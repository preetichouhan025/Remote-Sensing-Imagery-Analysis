# %% [markdown]
# <font color = 'Orange' size = 6> LandUse Dataset trained with VGG16 Architecture</font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
helper_methods_folder = '/content/drive/MyDrive/AI Project/helper_methods'

sys.path.append(os.path.abspath(helper_methods_folder))

# %% [markdown]
# **Importing helper methods for preprocessing, training and plotting**

# %%
from preprocessing import load_data
from plots import plot_data_loader, show_examples
from plots import plot_accuracy, plot_loss,plot_training_batch_loss, plot_confusion_matrix
from training import train_model, compute_accuracy_and_loss
from early_stopping import EarlyStopping
from metrics import compute_classification_report, compute_confusion_matrix
from unnormalize_images import UnNormalize
from predictions import predict_image_class

# %% [markdown]
# **Importing Libraries**

# %%
from torchvision import models
import torch.nn as nn
import torch
import matplotlib.pyplot as plt

# %%
root_dir = r'/content/drive/MyDrive/archive/images'
path_to_save_model=r"/content/drive/MyDrive/AI Project/LandUseResults"
file_name = "landuse_dataset_VGG"

# %% [markdown]
# **Load the datasets into train_loader, validation loader and test loader**

# %%
train_loader, test_loader, valid_loader, data = load_data(root_dir, test_split=0.2, val_split=0.1, batch_size=32, input_size=[64,64])

# %%
# checking the train loader dataset information
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Image batch dimensions: torch.Size([32, 3, 64, 64])
# Image label dimensions: torch.Size([32])
# Class labels of 10 examples: tensor([17,  6, 14,  5,  7, 16,  0,  5,  0, 12])

# %% [markdown]
# **Encodings for the classes**

# %%
label_encoding = data.class_to_idx  
print("label mapping is ", label_encoding)   # save these mapping for predicition
# Out:
# label mapping is  {'agricultural': 0, 'airplane': 1, 'baseballdiamond': 2, 'beach': 3, 'buildings': 4, 'chaparral': 5, 'denseresidential': 6, 'forest': 7, 'freeway': 8, 'golfcourse': 9, 'harbor': 10, 'intersection': 11, 'mediumresidential': 12, 'mobilehomepark': 13, 'overpass': 14, 'parkinglot': 15, 'river': 16, 'runway': 17, 'sparseresidential': 18, 'storagetanks': 19, 'tenniscourt': 20}

# %% [markdown]
# **Plot the data loader**

# %%
plot_data_loader(train_loader, (4,4))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Load VGG16 Model with Batch Normalization**

# %%
model = models.vgg16_bn()  # By default, no pre-trained weights are used.
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# **Change the number of outputs classes in the last layer of the model**

# %%
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, 21)  #num_classes = 21
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=21, bias=True)
#   )
# )

# %% [markdown]
# **Set the hyperparameters**

# %%
# define the loss function for multi-class classifictaion
criterion = nn.CrossEntropyLoss()

# criterion = torch.nn.functional.cross_entropy
#Adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0001)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 3, verbose=False)

# create and early stopping object which will be used during the training
early_stopping = EarlyStopping(tolerance=3, min_delta=0.01)

num_epochs = 40

# %% [markdown]
# **Train the Model with train_loader and perform validation with valid_loader**

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(42)
print("Device: {}".format(device))

model.to(device)

minibatch_loss_list, train_acc_list, valid_acc_list, train_loss_list, valid_loss_list = train_model(
    model=model,
    num_epochs=num_epochs,
    train_loader=train_loader,
    valid_loader=valid_loader,
    criterion = criterion,
    optimizer=optimizer,
    device=device,
    early_stopping=early_stopping,
    file_name = file_name,
    path_to_save_model=path_to_save_model,
    scheduler=scheduler)
# Out:
# Device: cuda:0
# Epoch: 001/040 | Batch 0000/0230 | Loss: 3.4073
# Epoch: 001/040 | Batch 0100/0230 | Loss: 2.9877
# Epoch: 001/040 | Batch 0200/0230 | Loss: 2.4446
# Epoch: 001/040 | Train ACC: 13.54% | Validation ACC: 16.57%| Train LOSS: 3.0209| Validation LOSS: 2.6876
# Time elapsed: 44.75 min
# Epoch: 002/040 | Batch 0000/0230 | Loss: 2.4791
# Epoch: 002/040 | Batch 0100/0230 | Loss: 2.0709
# Epoch: 002/040 | Batch 0200/0230 | Loss: 2.0956
# Epoch: 002/040 | Train ACC: 25.00% | Validation ACC: 34.38%| Train LOSS: 2.3774| Validation LOSS: 1.9874
# Time elapsed: 45.76 min
# Epoch: 003/040 | Batch 0000/0230 | Loss: 2.4824
# Epoch: 003/040 | Batch 0100/0230 | Loss: 1.8283
# Epoch: 003/040 | Batch 0200/0230 | Loss: 1.9503
# Epoch: 003/040 | Train ACC: 27.08% | Validation ACC: 43.24%| Train LOSS: 1.9028| Validation LOSS: 1.6797
# Time elapsed: 46.79 min
# Epoch: 004/040 | Batch 0000/0230 | Loss: 1.7610
# Epoch: 004/040 | Batch 0100/0230 | Loss: 1.9174
# Epoch: 004/040 | Batch 0200/0230 | Loss: 1.9996
# Epoch: 004/040 | Train ACC: 35.42% | Validation ACC: 44.29%| Train LOSS: 1.8085| Validation LOSS: 1.6412
# Time elapsed: 47.81 min
# Epoch: 005/040 | Batch 0000/0230 | Loss: 1.8597
# Epoch: 005/040 | Batch 0100/0230 | Loss: 1.6485
# Epoch: 005/040 | Batch 0200/0230 | Loss: 1.4854
# Epoch: 005/040 | Train ACC: 50.00% | Validation ACC: 51.52%| Train LOSS: 1.7001| Validation LOSS: 1.4056
# Time elapsed: 48.82 min
# Epoch: 006/040 | Batch 0000/0230 | Loss: 1.5133
# Epoch: 006/040 | Batch 0100/0230 | Loss: 1.6767
# Epoch: 006/040 | Batch 0200/0230 | Loss: 1.5187
# Epoch: 006/040 | Train ACC: 44.79% | Validation ACC: 54.10%| Train LOSS: 1.7198| Validation LOSS: 1.3722
# Time elapsed: 49.83 min
# Epoch: 007/040 | Batch 0000/0230 | Loss: 1.4298
# Epoch: 007/040 | Batch 0100/0230 | Loss: 1.4404
# Epoch: 007/040 | Batch 0200/0230 | Loss: 1.4534
# Epoch: 007/040 | Train ACC: 54.17% | Validation ACC: 58.86%| Train LOSS: 1.6336| Validation LOSS: 1.3062
# Time elapsed: 50.84 min
# Epoch: 008/040 | Batch 0000/0230 | Loss: 1.3943
# Epoch: 008/040 | Batch 0100/0230 | Loss: 1.4335
# Epoch: 008/040 | Batch 0200/0230 | Loss: 1.2354
# Epoch: 008/040 | Train ACC: 57.29% | Validation ACC: 61.52%| Train LOSS: 1.3049| Validation LOSS: 1.1496
# Time elapsed: 51.86 min
# Saving intermediate model weights
# Epoch: 009/040 | Batch 0000/0230 | Loss: 1.2237
# Epoch: 009/040 | Batch 0100/0230 | Loss: 0.9432
# Epoch: 009/040 | Batch 0200/0230 | Loss: 0.7858
# Epoch: 009/040 | Train ACC: 70.83% | Validation ACC: 74.19%| Train LOSS: 1.0157| Validation LOSS: 0.8056
# Time elapsed: 52.95 min
# Epoch: 010/040 | Batch 0000/0230 | Loss: 0.8113
# Epoch: 010/040 | Batch 0100/0230 | Loss: 0.9777
# Epoch: 010/040 | Batch 0200/0230 | Loss: 1.0933
# Epoch: 010/040 | Train ACC: 68.75% | Validation ACC: 76.38%| Train LOSS: 0.9130| Validation LOSS: 0.7530
# Time elapsed: 53.97 min
# Epoch: 011/040 | Batch 0000/0230 | Loss: 1.2712
# Epoch: 011/040 | Batch 0100/0230 | Loss: 1.2347
# Epoch: 011/040 | Batch 0200/0230 | Loss: 0.7797
# Epoch: 011/040 | Train ACC: 66.67% | Validation ACC: 77.33%| Train LOSS: 0.8973| Validation LOSS: 0.7081
# Time elapsed: 55.02 min
# Epoch: 012/040 | Batch 0000/0230 | Loss: 0.8822
# Epoch: 012/040 | Batch 0100/0230 | Loss: 1.0466
# Epoch: 012/040 | Batch 0200/0230 | Loss: 0.9286
# Epoch: 012/040 | Train ACC: 63.54% | Validation ACC: 67.24%| Train LOSS: 1.0645| Validation LOSS: 1.0670
# Time elapsed: 56.05 min
# Epoch: 013/040 | Batch 0000/0230 | Loss: 0.8501
# Epoch: 013/040 | Batch 0100/0230 | Loss: 1.2768
# Epoch: 013/040 | Batch 0200/0230 | Loss: 0.7029
# Epoch: 013/040 | Train ACC: 65.62% | Validation ACC: 69.05%| Train LOSS: 1.1059| Validation LOSS: 0.9985
# Time elapsed: 57.07 min
# Epoch: 014/040 | Batch 0000/0230 | Loss: 1.0864
# Epoch: 014/040 | Batch 0100/0230 | Loss: 0.8179
# Epoch: 014/040 | Batch 0200/0230 | Loss: 0.5415
# Epoch: 014/040 | Train ACC: 68.75% | Validation ACC: 73.14%| Train LOSS: 0.8961| Validation LOSS: 0.8250
# Time elapsed: 58.09 min
# Epoch: 015/040 | Batch 0000/0230 | Loss: 1.0563
# Epoch: 015/040 | Batch 0100/0230 | Loss: 0.8046
# Epoch: 015/040 | Batch 0200/0230 | Loss: 0.5035
# Epoch: 015/040 | Train ACC: 76.04% | Validation ACC: 83.90%| Train LOSS: 0.6567| Validation LOSS: 0.5082
# Time elapsed: 59.13 min
# Epoch: 016/040 | Batch 0000/0230 | Loss: 0.3598
# Epoch: 016/040 | Batch 0100/0230 | Loss: 0.4103
# Epoch: 016/040 | Batch 0200/0230 | Loss: 0.3195
# Epoch: 016/040 | Train ACC: 88.54% | Validation ACC: 83.14%| Train LOSS: 0.5615| Validation LOSS: 0.5310
# Time elapsed: 60.16 min
# Saving intermediate model weights
# Epoch: 017/040 | Batch 0000/0230 | Loss: 0.4227
# Epoch: 017/040 | Batch 0100/0230 | Loss: 0.7578
# Epoch: 017/040 | Batch 0200/0230 | Loss: 0.4387
# Epoch: 017/040 | Train ACC: 87.50% | Validation ACC: 84.38%| Train LOSS: 0.5511| Validation LOSS: 0.4711
# Time elapsed: 61.24 min
# Epoch: 018/040 | Batch 0000/0230 | Loss: 0.8006
# Epoch: 018/040 | Batch 0100/0230 | Loss: 0.9492
# Epoch: 018/040 | Batch 0200/0230 | Loss: 0.9230
# Epoch: 018/040 | Train ACC: 73.96% | Validation ACC: 78.67%| Train LOSS: 0.7199| Validation LOSS: 0.6777
# Time elapsed: 62.28 min
# Epoch: 019/040 | Batch 0000/0230 | Loss: 0.4959
# Epoch: 019/040 | Batch 0100/0230 | Loss: 0.7216
# Epoch: 019/040 | Batch 0200/0230 | Loss: 0.9200
# Epoch: 019/040 | Train ACC: 79.17% | Validation ACC: 74.38%| Train LOSS: 0.8100| Validation LOSS: 0.9212
# Time elapsed: 63.31 min
# Epoch: 020/040 | Batch 0000/0230 | Loss: 0.8219
# Epoch: 020/040 | Batch 0100/0230 | Loss: 0.7493
# Epoch: 020/040 | Batch 0200/0230 | Loss: 0.5640
# Epoch: 020/040 | Train ACC: 79.17% | Validation ACC: 78.48%| Train LOSS: 0.6340| Validation LOSS: 0.6889
# Time elapsed: 64.33 min
# Epoch: 021/040 | Batch 0000/0230 | Loss: 0.3819
# Epoch: 021/040 | Batch 0100/0230 | Loss: 0.4621
# Epoch: 021/040 | Batch 0200/0230 | Loss: 0.8013
# Epoch: 021/040 | Train ACC: 82.29% | Validation ACC: 89.43%| Train LOSS: 0.4318| Validation LOSS: 0.3528
# Time elapsed: 65.37 min
# Epoch: 022/040 | Batch 0000/0230 | Loss: 0.4072
# Epoch: 022/040 | Batch 0100/0230 | Loss: 0.4508
# Epoch: 022/040 | Batch 0200/0230 | Loss: 0.1862
# Epoch: 022/040 | Train ACC: 89.58% | Validation ACC: 87.90%| Train LOSS: 0.3799| Validation LOSS: 0.3689
# Time elapsed: 66.39 min
# Epoch: 023/040 | Batch 0000/0230 | Loss: 0.5960
# Epoch: 023/040 | Batch 0100/0230 | Loss: 0.2467
# Epoch: 023/040 | Batch 0200/0230 | Loss: 0.0886
# Epoch: 023/040 | Train ACC: 89.58% | Validation ACC: 88.76%| Train LOSS: 0.3546| Validation LOSS: 0.3464
# Early Stopping --- Saving the final model
# Final Model Saved. Training Complete!
# Total Training Time: 67.57 min
# Saving FINAL model weights

# %% [markdown]
# **Test Accuracy and test loss**

# %%
test_acc, test_loss= compute_accuracy_and_loss(model, test_loader,criterion, device=device)
print(f'Test Accuracy {test_acc :.2f}%')
print(f'Test Loss {test_loss :.4f}')
# Out:
# Test Accuracy 86.00%
# Test Loss 0.4400

# %% [markdown]
# **Plot the Training Mini_Batch_loss**

# %%
plot_training_batch_loss(minibatch_loss_list, num_epochs, len(train_loader))
plt.show()

# %% [markdown]
# **Plot train vs Validation Accuracy**

# %%
plot_accuracy(train_acc_list, valid_acc_list)
plt.show()

# %% [markdown]
# **Plot train vs Validation Loss**

# %%
plot_loss(train_loss_list, valid_loss_list)
plt.show()

# %% [markdown]
# **Saving the loss and accuracy into file for later model comparison**

# %%
landuse_dataset_output_dict = {"train_acc_list":train_acc_list,"valid_acc_list":valid_acc_list, "train_loss_list":train_loss_list, "valid_loss_list": valid_loss_list}

import json 

#writing this dict to a file for later use
with open('landuse_dataset_vgg3results.txt', 'w') as f:
    f.write(json.dumps(landuse_dataset_output_dict))


# for reading the file back into a Python object
# with open('./Satellite_dataset_results.txt, 'r') as f:
#     satellite_dataset_output_dict = json.loads(f.read())

# %% [markdown]
# **Confusion Matrix**

# %%
label_encoding = data.class_to_idx

class_dict = {v: k for k, v in label_encoding.items()} #reverse the mapping

print(label_encoding)
# Out:
# {'agricultural': 0, 'airplane': 1, 'baseballdiamond': 2, 'beach': 3, 'buildings': 4, 'chaparral': 5, 'denseresidential': 6, 'forest': 7, 'freeway': 8, 'golfcourse': 9, 'harbor': 10, 'intersection': 11, 'mediumresidential': 12, 'mobilehomepark': 13, 'overpass': 14, 'parkinglot': 15, 'river': 16, 'runway': 17, 'sparseresidential': 18, 'storagetanks': 19, 'tenniscourt': 20}

# %%
# label_encoding = {'cloudy': 0, 'desert': 1, 'green_area': 2, 'water': 3}  # assign to a variable as it will be needed while prediciting

# %%
confusion_matrix = compute_confusion_matrix(model = model, data_loader = test_loader, device=torch.device('cuda:0'))
plot_confusion_matrix(confusion_matrix, class_names = class_dict.values())
plt.show()

# %% [markdown]
# **F1 Score, Precision and Recall**

# %%
print(compute_classification_report(test_loader, model, device=torch.device('cuda') ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90       101
#            1       0.92      0.94      0.93        95
#            2       0.92      0.93      0.92        98
#            3       0.95      0.82      0.88       107
#            4       0.73      0.61      0.66       119
#            5       0.93      1.00      0.96       105
#            6       0.70      0.57      0.63       120
#            7       0.97      0.91      0.94       122
#            8       0.89      0.83      0.86       116
#            9       0.80      0.94      0.86        96
#           10       1.00      0.99      0.99        83
#           11       0.84      0.90      0.87        97
#           12       0.63      0.65      0.64       100
#           13       0.82      0.90      0.86        84
#           14       0.85      0.79      0.82        94
#           15       1.00      0.97      0.99       107
#           16       0.84      0.89      0.86        88
#           17       0.97      0.94      0.95        96
#           18       0.77      0.83      0.80        88
#           19       0.64      0.81      0.71        83
#           20       0.78      0.81      0.80       101
#
#     accuracy                           0.85      2100
#    macro avg       0.85      0.85      0.85      2100
# weighted avg       0.85      0.85      0.85      2100

# %% [markdown]
# **Predicted labels Visualization**

# %%
model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %% [markdown]
# **Load the saved model to make predictions**

# %%
model  = torch.load(path_to_save_model + file_name+'_FINAL_MODEL_WEIGHTS.pth', map_location=torch.device('cpu'))

# %%
# test image path 
img_path = '/content/drive/MyDrive/AI Project/buildings.png'

# %%
classes = ['agricultural', 'airplane', 'baseballdiamond', 'beach', 'buildings', 'chaparral', 'denseresidential', 'forest', 'freeway', 'golfcourse', 'harbor', 'intersection', 'mediumresidential', 'mobilehomepark', 'overpass', 'parkinglot', 'river', 'runway', 'sparseresidential', 'storagetanks', 'tenniscourt']
print("The predicted class is " , predict_image_class(model, img_path, classes))
# Out:
# The predicted class is  forest
