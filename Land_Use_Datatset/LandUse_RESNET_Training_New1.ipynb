# %% [markdown]
# <font color = 'Orange' size = 6> LandUse Dataset trained with ResNet50 Architecture</font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
helper_methods_folder = '/content/drive/MyDrive/AI Project/helper_methods'

sys.path.append(os.path.abspath(helper_methods_folder))

# %% [markdown]
# **Importing helper methods for preprocessing, training and plotting**

# %%
from preprocessing import load_data
from plots import plot_data_loader, show_examples
from plots import plot_accuracy, plot_loss,plot_training_batch_loss, plot_confusion_matrix
from training import train_model, compute_accuracy_and_loss
from early_stopping import EarlyStopping
from metrics import compute_classification_report, compute_confusion_matrix
from unnormalize_images import UnNormalize
from predictions import predict_image_class

# %% [markdown]
# **Importing Libraries**

# %%
from torchvision import models
import torch.nn as nn
import torch
import matplotlib.pyplot as plt

# %%
root_dir = r'/content/drive/MyDrive/archive/images'
path_to_save_model=r"/content/drive/MyDrive/AI Project/LandUseResults"
file_name = "landuse_dataset_RESNET1"

# %% [markdown]
# **Load the datasets into train_loader, validation loader and test loader**

# %%
train_loader, test_loader, valid_loader, data = load_data(root_dir, test_split=0.2, val_split=0.1, batch_size=32, input_size=[128,128])

# %%
# checking the train loader dataset information
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Image batch dimensions: torch.Size([32, 3, 128, 128])
# Image label dimensions: torch.Size([32])
# Class labels of 10 examples: tensor([11,  1,  9, 18,  3, 20, 12, 14, 11, 20])

# %% [markdown]
# **Encodings for the classes**

# %%
label_encoding = data.class_to_idx  
print("label mapping is ", label_encoding)   # save these mapping for predicition
# Out:
# label mapping is  {'agricultural': 0, 'airplane': 1, 'baseballdiamond': 2, 'beach': 3, 'buildings': 4, 'chaparral': 5, 'denseresidential': 6, 'forest': 7, 'freeway': 8, 'golfcourse': 9, 'harbor': 10, 'intersection': 11, 'mediumresidential': 12, 'mobilehomepark': 13, 'overpass': 14, 'parkinglot': 15, 'river': 16, 'runway': 17, 'sparseresidential': 18, 'storagetanks': 19, 'tenniscourt': 20}

# %% [markdown]
# **Plot the data loader**

# %%
plot_data_loader(train_loader, (4,4))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Load RESNET50 Model**

# %%
model = models.resnet50(pretrained=False) # By default, no pre-trained weights are used.
print(model)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %% [markdown]
# **Change the number of outputs classes in the last layer of the model**

# %%
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 21) #num_classes = 21
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=21, bias=True)
# )

# %% [markdown]
# **Set the hyperparameters**

# %%
# define the loss function for multi-class classifictaion
criterion = nn.CrossEntropyLoss()

# criterion = torch.nn.functional.cross_entropy
#Adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0001)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 3, verbose=False)

# create and early stopping object which will be used during the training
early_stopping = EarlyStopping(tolerance=3, min_delta=0.01)

num_epochs = 40

# %% [markdown]
# **Train the Model with train_loader and perform validation with valid_loader**

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(42)
print("Device: {}".format(device))

model.to(device)

minibatch_loss_list, train_acc_list, valid_acc_list, train_loss_list, valid_loss_list = train_model(
    model=model,
    num_epochs=num_epochs,
    train_loader=train_loader,
    valid_loader=valid_loader,
    criterion = criterion,
    optimizer=optimizer,
    device=device,
    early_stopping=early_stopping,
    file_name = file_name,
    path_to_save_model=path_to_save_model,
    scheduler=scheduler)
# Out:
# Device: cuda:0
# Epoch: 001/040 | Batch 0000/0230 | Loss: 2.9527
# Epoch: 001/040 | Batch 0100/0230 | Loss: 2.6611
# Epoch: 001/040 | Batch 0200/0230 | Loss: 2.5282
# Epoch: 001/040 | Train ACC: 14.58% | Validation ACC: 26.57%| Train LOSS: 2.7034| Validation LOSS: 2.4183
# Time elapsed: 67.16 min
# Epoch: 002/040 | Batch 0000/0230 | Loss: 2.4151
# Epoch: 002/040 | Batch 0100/0230 | Loss: 2.2467
# Epoch: 002/040 | Batch 0200/0230 | Loss: 1.9403
# Epoch: 002/040 | Train ACC: 31.25% | Validation ACC: 37.24%| Train LOSS: 2.1267| Validation LOSS: 1.9439
# Time elapsed: 68.26 min
# Epoch: 003/040 | Batch 0000/0230 | Loss: 1.8631
# Epoch: 003/040 | Batch 0100/0230 | Loss: 1.4764
# Epoch: 003/040 | Batch 0200/0230 | Loss: 1.8623
# Epoch: 003/040 | Train ACC: 48.96% | Validation ACC: 45.43%| Train LOSS: 1.8102| Validation LOSS: 1.7078
# Time elapsed: 69.38 min
# Epoch: 004/040 | Batch 0000/0230 | Loss: 1.8292
# Epoch: 004/040 | Batch 0100/0230 | Loss: 1.3792
# Epoch: 004/040 | Batch 0200/0230 | Loss: 1.5701
# Epoch: 004/040 | Train ACC: 53.12% | Validation ACC: 44.10%| Train LOSS: 1.7501| Validation LOSS: 1.6829
# Time elapsed: 70.50 min
# Epoch: 005/040 | Batch 0000/0230 | Loss: 1.8914
# Epoch: 005/040 | Batch 0100/0230 | Loss: 1.7632
# Epoch: 005/040 | Batch 0200/0230 | Loss: 1.7828
# Epoch: 005/040 | Train ACC: 43.75% | Validation ACC: 48.00%| Train LOSS: 1.7043| Validation LOSS: 1.5936
# Time elapsed: 71.61 min
# Epoch: 006/040 | Batch 0000/0230 | Loss: 1.4527
# Epoch: 006/040 | Batch 0100/0230 | Loss: 1.9288
# Epoch: 006/040 | Batch 0200/0230 | Loss: 1.9143
# Epoch: 006/040 | Train ACC: 43.75% | Validation ACC: 44.10%| Train LOSS: 1.7190| Validation LOSS: 1.7308
# Time elapsed: 72.71 min
# Epoch: 007/040 | Batch 0000/0230 | Loss: 2.0723
# Epoch: 007/040 | Batch 0100/0230 | Loss: 1.4483
# Epoch: 007/040 | Batch 0200/0230 | Loss: 1.4329
# Epoch: 007/040 | Train ACC: 47.92% | Validation ACC: 49.90%| Train LOSS: 1.6506| Validation LOSS: 1.5619
# Time elapsed: 73.83 min
# Epoch: 008/040 | Batch 0000/0230 | Loss: 1.6558
# Epoch: 008/040 | Batch 0100/0230 | Loss: 1.6378
# Epoch: 008/040 | Batch 0200/0230 | Loss: 1.3151
# Epoch: 008/040 | Train ACC: 48.96% | Validation ACC: 56.19%| Train LOSS: 1.4447| Validation LOSS: 1.3631
# Time elapsed: 74.93 min
# Saving intermediate model weights
# Epoch: 009/040 | Batch 0000/0230 | Loss: 1.3415
# Epoch: 009/040 | Batch 0100/0230 | Loss: 1.1601
# Epoch: 009/040 | Batch 0200/0230 | Loss: 1.2687
# Epoch: 009/040 | Train ACC: 54.17% | Validation ACC: 61.52%| Train LOSS: 1.2499| Validation LOSS: 1.1669
# Time elapsed: 76.05 min
# Epoch: 010/040 | Batch 0000/0230 | Loss: 1.2632
# Epoch: 010/040 | Batch 0100/0230 | Loss: 1.3701
# Epoch: 010/040 | Batch 0200/0230 | Loss: 0.8276
# Epoch: 010/040 | Train ACC: 62.50% | Validation ACC: 62.00%| Train LOSS: 1.1966| Validation LOSS: 1.1886
# Time elapsed: 77.15 min
# Epoch: 011/040 | Batch 0000/0230 | Loss: 1.4898
# Epoch: 011/040 | Batch 0100/0230 | Loss: 0.9486
# Epoch: 011/040 | Batch 0200/0230 | Loss: 1.0966
# Epoch: 011/040 | Train ACC: 59.38% | Validation ACC: 63.14%| Train LOSS: 1.1766| Validation LOSS: 1.1349
# Time elapsed: 78.25 min
# Epoch: 012/040 | Batch 0000/0230 | Loss: 0.8875
# Epoch: 012/040 | Batch 0100/0230 | Loss: 1.1706
# Epoch: 012/040 | Batch 0200/0230 | Loss: 0.9299
# Epoch: 012/040 | Train ACC: 66.67% | Validation ACC: 61.14%| Train LOSS: 1.2543| Validation LOSS: 1.1753
# Time elapsed: 79.36 min
# Epoch: 013/040 | Batch 0000/0230 | Loss: 0.9250
# Epoch: 013/040 | Batch 0100/0230 | Loss: 1.3140
# Epoch: 013/040 | Batch 0200/0230 | Loss: 1.4117
# Epoch: 013/040 | Train ACC: 60.42% | Validation ACC: 61.81%| Train LOSS: 1.2555| Validation LOSS: 1.1409
# Time elapsed: 80.46 min
# Epoch: 014/040 | Batch 0000/0230 | Loss: 1.3334
# Epoch: 014/040 | Batch 0100/0230 | Loss: 1.0904
# Epoch: 014/040 | Batch 0200/0230 | Loss: 0.7828
# Epoch: 014/040 | Train ACC: 68.75% | Validation ACC: 63.71%| Train LOSS: 1.0658| Validation LOSS: 1.1093
# Time elapsed: 81.55 min
# Epoch: 015/040 | Batch 0000/0230 | Loss: 1.0609
# Epoch: 015/040 | Batch 0100/0230 | Loss: 0.6569
# Epoch: 015/040 | Batch 0200/0230 | Loss: 0.9667
# Epoch: 015/040 | Train ACC: 75.00% | Validation ACC: 71.05%| Train LOSS: 0.8650| Validation LOSS: 0.8504
# Time elapsed: 82.66 min
# Epoch: 016/040 | Batch 0000/0230 | Loss: 0.9704
# Epoch: 016/040 | Batch 0100/0230 | Loss: 1.0601
# Epoch: 016/040 | Batch 0200/0230 | Loss: 0.6694
# Epoch: 016/040 | Train ACC: 67.71% | Validation ACC: 71.90%| Train LOSS: 0.8147| Validation LOSS: 0.8497
# Time elapsed: 83.75 min
# Saving intermediate model weights
# Epoch: 017/040 | Batch 0000/0230 | Loss: 0.7559
# Epoch: 017/040 | Batch 0100/0230 | Loss: 0.6380
# Epoch: 017/040 | Batch 0200/0230 | Loss: 0.6244
# Epoch: 017/040 | Train ACC: 77.08% | Validation ACC: 72.29%| Train LOSS: 0.8164| Validation LOSS: 0.8435
# Time elapsed: 84.85 min
# Epoch: 018/040 | Batch 0000/0230 | Loss: 0.7735
# Epoch: 018/040 | Batch 0100/0230 | Loss: 0.6471
# Epoch: 018/040 | Batch 0200/0230 | Loss: 0.5189
# Epoch: 018/040 | Train ACC: 81.25% | Validation ACC: 68.38%| Train LOSS: 0.9024| Validation LOSS: 0.9528
# Time elapsed: 85.95 min
# Epoch: 019/040 | Batch 0000/0230 | Loss: 0.6995
# Epoch: 019/040 | Batch 0100/0230 | Loss: 1.4736
# Epoch: 019/040 | Batch 0200/0230 | Loss: 1.2850
# Epoch: 019/040 | Train ACC: 60.42% | Validation ACC: 64.67%| Train LOSS: 0.9306| Validation LOSS: 1.0884
# Time elapsed: 87.04 min
# Epoch: 020/040 | Batch 0000/0230 | Loss: 1.0245
# Epoch: 020/040 | Batch 0100/0230 | Loss: 0.6710
# Epoch: 020/040 | Batch 0200/0230 | Loss: 0.5938
# Epoch: 020/040 | Train ACC: 73.96% | Validation ACC: 71.33%| Train LOSS: 0.7925| Validation LOSS: 0.8729
# Time elapsed: 88.13 min
# Epoch: 021/040 | Batch 0000/0230 | Loss: 0.8075
# Epoch: 021/040 | Batch 0100/0230 | Loss: 0.5737
# Epoch: 021/040 | Batch 0200/0230 | Loss: 0.6947
# Epoch: 021/040 | Train ACC: 73.96% | Validation ACC: 77.33%| Train LOSS: 0.6088| Validation LOSS: 0.6621
# Time elapsed: 89.23 min
# Epoch: 022/040 | Batch 0000/0230 | Loss: 0.3578
# Epoch: 022/040 | Batch 0100/0230 | Loss: 0.5349
# Epoch: 022/040 | Batch 0200/0230 | Loss: 0.6247
# Epoch: 022/040 | Train ACC: 84.38% | Validation ACC: 78.86%| Train LOSS: 0.5484| Validation LOSS: 0.6192
# Time elapsed: 90.32 min
# Epoch: 023/040 | Batch 0000/0230 | Loss: 0.5737
# Epoch: 023/040 | Batch 0100/0230 | Loss: 0.5868
# Epoch: 023/040 | Batch 0200/0230 | Loss: 0.2282
# Epoch: 023/040 | Train ACC: 85.42% | Validation ACC: 77.52%| Train LOSS: 0.5538| Validation LOSS: 0.6479
# Time elapsed: 91.41 min
# Epoch: 024/040 | Batch 0000/0230 | Loss: 0.3516
# Epoch: 024/040 | Batch 0100/0230 | Loss: 0.6599
# Epoch: 024/040 | Batch 0200/0230 | Loss: 0.5612
# Epoch: 024/040 | Train ACC: 85.42% | Validation ACC: 74.86%| Train LOSS: 0.6919| Validation LOSS: 0.7787
# Time elapsed: 92.51 min
# Saving intermediate model weights
# Epoch: 025/040 | Batch 0000/0230 | Loss: 0.7897
# Epoch: 025/040 | Batch 0100/0230 | Loss: 0.4588
# Epoch: 025/040 | Batch 0200/0230 | Loss: 0.5154
# Epoch: 025/040 | Train ACC: 83.33% | Validation ACC: 70.38%| Train LOSS: 0.7404| Validation LOSS: 0.9252
# Time elapsed: 93.60 min
# Epoch: 026/040 | Batch 0000/0230 | Loss: 0.7180
# Epoch: 026/040 | Batch 0100/0230 | Loss: 0.2326
# Epoch: 026/040 | Batch 0200/0230 | Loss: 0.3305
# Epoch: 026/040 | Train ACC: 89.58% | Validation ACC: 78.76%| Train LOSS: 0.5869| Validation LOSS: 0.6297
# Time elapsed: 94.70 min
# Epoch: 027/040 | Batch 0000/0230 | Loss: 0.5988
# Epoch: 027/040 | Batch 0100/0230 | Loss: 0.8172
# Epoch: 027/040 | Batch 0200/0230 | Loss: 0.3240
# Epoch: 027/040 | Train ACC: 79.17% | Validation ACC: 81.33%| Train LOSS: 0.4244| Validation LOSS: 0.5323
# Time elapsed: 95.79 min
# Epoch: 028/040 | Batch 0000/0230 | Loss: 0.3904
# Epoch: 028/040 | Batch 0100/0230 | Loss: 0.3357
# Epoch: 028/040 | Batch 0200/0230 | Loss: 0.3453
# Epoch: 028/040 | Train ACC: 90.62% | Validation ACC: 83.43%| Train LOSS: 0.3677| Validation LOSS: 0.4871
# Time elapsed: 96.88 min
# Epoch: 029/040 | Batch 0000/0230 | Loss: 0.4196
# Epoch: 029/040 | Batch 0100/0230 | Loss: 0.3582
# Epoch: 029/040 | Batch 0200/0230 | Loss: 0.2769
# Epoch: 029/040 | Train ACC: 86.46% | Validation ACC: 82.29%| Train LOSS: 0.3840| Validation LOSS: 0.5104
# Time elapsed: 97.98 min
# Epoch: 030/040 | Batch 0000/0230 | Loss: 0.3183
# Epoch: 030/040 | Batch 0100/0230 | Loss: 0.8610
# Epoch: 030/040 | Batch 0200/0230 | Loss: 0.8361
# Epoch: 030/040 | Train ACC: 75.00% | Validation ACC: 76.86%| Train LOSS: 0.5093| Validation LOSS: 0.7295
# Time elapsed: 99.06 min
# Epoch: 031/040 | Batch 0000/0230 | Loss: 0.3415
# Epoch: 031/040 | Batch 0100/0230 | Loss: 0.7126
# Epoch: 031/040 | Batch 0200/0230 | Loss: 0.2703
# Epoch: 031/040 | Train ACC: 87.50% | Validation ACC: 77.81%| Train LOSS: 0.5886| Validation LOSS: 0.7024
# Time elapsed: 100.15 min
# Epoch: 032/040 | Batch 0000/0230 | Loss: 0.6404
# Epoch: 032/040 | Batch 0100/0230 | Loss: 0.3459
# Epoch: 032/040 | Batch 0200/0230 | Loss: 0.3601
# Epoch: 032/040 | Train ACC: 86.46% | Validation ACC: 80.86%| Train LOSS: 0.4494| Validation LOSS: 0.5323
# Time elapsed: 101.25 min
# Saving intermediate model weights
# Epoch: 033/040 | Batch 0000/0230 | Loss: 0.4052
# Epoch: 033/040 | Batch 0100/0230 | Loss: 0.1005
# Epoch: 033/040 | Batch 0200/0230 | Loss: 0.1673
# Epoch: 033/040 | Train ACC: 93.75% | Validation ACC: 85.43%| Train LOSS: 0.2857| Validation LOSS: 0.4705
# Early Stopping --- Saving the final model
# Final Model Saved. Training Complete!
# Total Training Time: 102.35 min
# Saving FINAL model weights

# %% [markdown]
# **Test Accuracy and test loss**

# %%
test_acc, test_loss= compute_accuracy_and_loss(model, test_loader,criterion, device=device)
print(f'Test Accuracy {test_acc :.2f}%')
print(f'Test Loss {test_loss :.4f}')
# Out:
# Test Accuracy 83.76%
# Test Loss 0.4824

# %% [markdown]
# **Plot the Training Mini_Batch_loss**

# %%
plot_training_batch_loss(minibatch_loss_list, num_epochs, len(train_loader))
plt.show()

# %% [markdown]
# **Plot train vs Validation Accuracy**

# %%
plot_accuracy(train_acc_list, valid_acc_list)
plt.show()

# %% [markdown]
# **Plot train vs Validation Loss**

# %%
plot_loss(train_loss_list, valid_loss_list)
plt.show()

# %% [markdown]
# **Saving the loss and accuracy into file for later model comparison**

# %%
landuse_dataset_output_dict = {"train_acc_list":train_acc_list,"valid_acc_list":valid_acc_list, "train_loss_list":train_loss_list, "valid_loss_list": valid_loss_list}

import json 

#writing this dict to a file for later use
with open('landuse_dataset_resnet1results.txt', 'w') as f:
    f.write(json.dumps(landuse_dataset_output_dict))


# for reading the file back into a Python object
# with open('./Satellite_dataset_results.txt, 'r') as f:
#     satellite_dataset_output_dict = json.loads(f.read())

# %% [markdown]
# **Confusion Matrix**

# %%
label_encoding = data.class_to_idx

class_dict = {v: k for k, v in label_encoding.items()} #reverse the mapping

print(label_encoding)
# Out:
# {'agricultural': 0, 'airplane': 1, 'baseballdiamond': 2, 'beach': 3, 'buildings': 4, 'chaparral': 5, 'denseresidential': 6, 'forest': 7, 'freeway': 8, 'golfcourse': 9, 'harbor': 10, 'intersection': 11, 'mediumresidential': 12, 'mobilehomepark': 13, 'overpass': 14, 'parkinglot': 15, 'river': 16, 'runway': 17, 'sparseresidential': 18, 'storagetanks': 19, 'tenniscourt': 20}

# %%
# label_encoding = {'cloudy': 0, 'desert': 1, 'green_area': 2, 'water': 3}  # assign to a variable as it will be needed while prediciting

# %%
confusion_matrix = compute_confusion_matrix(model = model, data_loader = test_loader, device=torch.device('cuda:0'))
plot_confusion_matrix(confusion_matrix, class_names = class_dict.values())
plt.show()

# %% [markdown]
# **F1 Score, Precision and Recall**

# %%
print(compute_classification_report(test_loader, model, device=torch.device('cuda') ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90        83
#            1       0.91      0.94      0.92        85
#            2       0.90      0.93      0.92        87
#            3       0.97      0.90      0.93       111
#            4       0.78      0.65      0.71       134
#            5       1.00      0.90      0.95       113
#            6       0.76      0.66      0.71        95
#            7       0.94      0.87      0.91       111
#            8       0.82      0.86      0.84       118
#            9       0.84      0.83      0.83        92
#           10       0.97      0.96      0.97       101
#           11       0.83      0.82      0.83        95
#           12       0.68      0.70      0.69        99
#           13       0.93      0.89      0.91        95
#           14       0.77      0.83      0.80        94
#           15       0.97      0.96      0.97       102
#           16       0.85      0.91      0.88        93
#           17       0.89      0.91      0.90       106
#           18       0.79      0.76      0.78       105
#           19       0.55      0.68      0.61        91
#           20       0.69      0.78      0.73        90
#
#     accuracy                           0.84      2100
#    macro avg       0.84      0.84      0.84      2100
# weighted avg       0.85      0.84      0.84      2100

# %% [markdown]
# **Predicted labels Visualization**

# %%
model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %% [markdown]
# **Load the saved model to make predictions**

# %%
model  = torch.load(path_to_save_model + file_name+'_FINAL_MODEL_WEIGHTS.pth', map_location=torch.device('cpu'))

# %%
# test image path 
img_path = '/content/drive/MyDrive/AI Project/buildings.png'

# %%
classes = ['agricultural', 'airplane', 'baseballdiamond', 'beach', 'buildings', 'chaparral', 'denseresidential', 'forest', 'freeway', 'golfcourse', 'harbor', 'intersection', 'mediumresidential', 'mobilehomepark', 'overpass', 'parkinglot', 'river', 'runway', 'sparseresidential', 'storagetanks', 'tenniscourt']
print("The predicted class is " , predict_image_class(model, img_path, classes))
# Out:
# The predicted class is  chaparral
