# %% [markdown]
# <font color = 'Orange' size = 6> LandUse Dataset trained with VGG16 Architecture</font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
helper_methods_folder = '/content/drive/MyDrive/AI Project/helper_methods'

sys.path.append(os.path.abspath(helper_methods_folder))

# %% [markdown]
# **Importing helper methods for preprocessing, training and plotting**

# %%
from preprocessing import load_data
from plots import plot_data_loader, show_examples
from plots import plot_accuracy, plot_loss,plot_training_batch_loss, plot_confusion_matrix
from training import train_model, compute_accuracy_and_loss
from early_stopping import EarlyStopping
from metrics import compute_classification_report, compute_confusion_matrix
from unnormalize_images import UnNormalize
from predictions import predict_image_class

# %% [markdown]
# **Importing Libraries**

# %%
from torchvision import models
import torch.nn as nn
import torch
import matplotlib.pyplot as plt

# %%
root_dir = r'/content/drive/MyDrive/archive/images'
path_to_save_model=r"/content/drive/MyDrive/AI Project/LandUseResults"
file_name = "landuse_dataset_VGG"

# %% [markdown]
# **Load the datasets into train_loader, validation loader and test loader**

# %%
train_loader, test_loader, valid_loader, data = load_data(root_dir, test_split=0.2, val_split=0.1, batch_size=32, input_size=[64,64])

# %%
# checking the train loader dataset information
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Image batch dimensions: torch.Size([32, 3, 64, 64])
# Image label dimensions: torch.Size([32])
# Class labels of 10 examples: tensor([19,  7,  9,  7, 14,  4,  2, 17, 13, 12])

# %% [markdown]
# **Encodings for the classes**

# %%
label_encoding = data.class_to_idx  
print("label mapping is ", label_encoding)   # save these mapping for predicition
# Out:
# label mapping is  {'agricultural': 0, 'airplane': 1, 'baseballdiamond': 2, 'beach': 3, 'buildings': 4, 'chaparral': 5, 'denseresidential': 6, 'forest': 7, 'freeway': 8, 'golfcourse': 9, 'harbor': 10, 'intersection': 11, 'mediumresidential': 12, 'mobilehomepark': 13, 'overpass': 14, 'parkinglot': 15, 'river': 16, 'runway': 17, 'sparseresidential': 18, 'storagetanks': 19, 'tenniscourt': 20}

# %% [markdown]
# **Plot the data loader**

# %%
plot_data_loader(train_loader, (4,4))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Load VGG16 Model with Batch Normalization**

# %%
model = models.vgg16_bn()  # By default, no pre-trained weights are used.
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# **Change the number of outputs classes in the last layer of the model**

# %%
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, 21)  #num_classes = 21
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=21, bias=True)
#   )
# )

# %% [markdown]
# **Set the hyperparameters**

# %%
# define the loss function for multi-class classifictaion
criterion = nn.CrossEntropyLoss()

# criterion = torch.nn.functional.cross_entropy
#Adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0001)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 3, verbose=False)

# create and early stopping object which will be used during the training
early_stopping = EarlyStopping(tolerance=3, min_delta=0.01)

num_epochs = 40

# %% [markdown]
# **Train the Model with train_loader and perform validation with valid_loader**

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(42)
print("Device: {}".format(device))

model.to(device)

minibatch_loss_list, train_acc_list, valid_acc_list, train_loss_list, valid_loss_list = train_model(
    model=model,
    num_epochs=num_epochs,
    train_loader=train_loader,
    valid_loader=valid_loader,
    criterion = criterion,
    optimizer=optimizer,
    device=device,
    early_stopping=early_stopping,
    file_name = file_name,
    path_to_save_model=path_to_save_model,
    scheduler=scheduler)
# Out:
# Device: cuda:0
# Epoch: 001/040 | Batch 0000/0230 | Loss: 3.1680
# Epoch: 001/040 | Batch 0100/0230 | Loss: 2.7796
# Epoch: 001/040 | Batch 0200/0230 | Loss: 2.3711
# Epoch: 001/040 | Train ACC: 12.50% | Validation ACC: 22.10%| Train LOSS: 3.0015| Validation LOSS: 2.3961
# Time elapsed: 39.63 min
# Epoch: 002/040 | Batch 0000/0230 | Loss: 2.7177
# Epoch: 002/040 | Batch 0100/0230 | Loss: 2.3989
# Epoch: 002/040 | Batch 0200/0230 | Loss: 2.0818
# Epoch: 002/040 | Train ACC: 23.96% | Validation ACC: 35.52%| Train LOSS: 2.2894| Validation LOSS: 2.0491
# Time elapsed: 40.66 min
# Epoch: 003/040 | Batch 0000/0230 | Loss: 2.0533
# Epoch: 003/040 | Batch 0100/0230 | Loss: 1.9588
# Epoch: 003/040 | Batch 0200/0230 | Loss: 2.2674
# Epoch: 003/040 | Train ACC: 36.46% | Validation ACC: 44.10%| Train LOSS: 1.8915| Validation LOSS: 1.6688
# Time elapsed: 41.69 min
# Epoch: 004/040 | Batch 0000/0230 | Loss: 1.5163
# Epoch: 004/040 | Batch 0100/0230 | Loss: 1.8343
# Epoch: 004/040 | Batch 0200/0230 | Loss: 1.9192
# Epoch: 004/040 | Train ACC: 37.50% | Validation ACC: 46.48%| Train LOSS: 1.7498| Validation LOSS: 1.5891
# Time elapsed: 42.71 min
# Epoch: 005/040 | Batch 0000/0230 | Loss: 2.0455
# Epoch: 005/040 | Batch 0100/0230 | Loss: 1.5914
# Epoch: 005/040 | Batch 0200/0230 | Loss: 2.0311
# Epoch: 005/040 | Train ACC: 37.50% | Validation ACC: 49.90%| Train LOSS: 1.7459| Validation LOSS: 1.4716
# Time elapsed: 43.75 min
# Epoch: 006/040 | Batch 0000/0230 | Loss: 1.7104
# Epoch: 006/040 | Batch 0100/0230 | Loss: 1.6026
# Epoch: 006/040 | Batch 0200/0230 | Loss: 1.5108
# Epoch: 006/040 | Train ACC: 40.62% | Validation ACC: 46.76%| Train LOSS: 1.7397| Validation LOSS: 1.6387
# Time elapsed: 44.78 min
# Epoch: 007/040 | Batch 0000/0230 | Loss: 1.6009
# Epoch: 007/040 | Batch 0100/0230 | Loss: 1.8453
# Epoch: 007/040 | Batch 0200/0230 | Loss: 1.6969
# Epoch: 007/040 | Train ACC: 50.00% | Validation ACC: 47.81%| Train LOSS: 1.6293| Validation LOSS: 1.6022
# Time elapsed: 45.81 min
# Epoch: 008/040 | Batch 0000/0230 | Loss: 1.4216
# Epoch: 008/040 | Batch 0100/0230 | Loss: 1.0769
# Epoch: 008/040 | Batch 0200/0230 | Loss: 1.3477
# Epoch: 008/040 | Train ACC: 60.42% | Validation ACC: 62.57%| Train LOSS: 1.3337| Validation LOSS: 1.1810
# Time elapsed: 46.82 min
# Saving intermediate model weights
# Epoch: 009/040 | Batch 0000/0230 | Loss: 1.3641
# Epoch: 009/040 | Batch 0100/0230 | Loss: 1.0353
# Epoch: 009/040 | Batch 0200/0230 | Loss: 1.0262
# Epoch: 009/040 | Train ACC: 67.71% | Validation ACC: 70.57%| Train LOSS: 1.0342| Validation LOSS: 0.8834
# Time elapsed: 47.92 min
# Epoch: 010/040 | Batch 0000/0230 | Loss: 0.8375
# Epoch: 010/040 | Batch 0100/0230 | Loss: 1.2761
# Epoch: 010/040 | Batch 0200/0230 | Loss: 0.7040
# Epoch: 010/040 | Train ACC: 66.67% | Validation ACC: 70.95%| Train LOSS: 0.9439| Validation LOSS: 0.8648
# Time elapsed: 48.97 min
# Epoch: 011/040 | Batch 0000/0230 | Loss: 0.8311
# Epoch: 011/040 | Batch 0100/0230 | Loss: 0.8940
# Epoch: 011/040 | Batch 0200/0230 | Loss: 0.4912
# Epoch: 011/040 | Train ACC: 78.12% | Validation ACC: 70.57%| Train LOSS: 0.9228| Validation LOSS: 0.8319
# Time elapsed: 50.02 min
# Epoch: 012/040 | Batch 0000/0230 | Loss: 1.3222
# Epoch: 012/040 | Batch 0100/0230 | Loss: 1.0083
# Epoch: 012/040 | Batch 0200/0230 | Loss: 1.1999
# Epoch: 012/040 | Train ACC: 60.42% | Validation ACC: 68.00%| Train LOSS: 1.0916| Validation LOSS: 1.0506
# Time elapsed: 51.05 min
# Epoch: 013/040 | Batch 0000/0230 | Loss: 0.7820
# Epoch: 013/040 | Batch 0100/0230 | Loss: 1.4038
# Epoch: 013/040 | Batch 0200/0230 | Loss: 1.0451
# Epoch: 013/040 | Train ACC: 63.54% | Validation ACC: 61.43%| Train LOSS: 1.0988| Validation LOSS: 1.4117
# Time elapsed: 52.09 min
# Epoch: 014/040 | Batch 0000/0230 | Loss: 1.3254
# Epoch: 014/040 | Batch 0100/0230 | Loss: 1.2401
# Epoch: 014/040 | Batch 0200/0230 | Loss: 0.6446
# Epoch: 014/040 | Train ACC: 63.54% | Validation ACC: 70.57%| Train LOSS: 0.9178| Validation LOSS: 0.8847
# Time elapsed: 53.13 min
# Epoch: 015/040 | Batch 0000/0230 | Loss: 0.7282
# Epoch: 015/040 | Batch 0100/0230 | Loss: 0.5790
# Epoch: 015/040 | Batch 0200/0230 | Loss: 0.5695
# Epoch: 015/040 | Train ACC: 79.17% | Validation ACC: 79.43%| Train LOSS: 0.6555| Validation LOSS: 0.6265
# Time elapsed: 54.17 min
# Epoch: 016/040 | Batch 0000/0230 | Loss: 0.4739
# Epoch: 016/040 | Batch 0100/0230 | Loss: 0.6652
# Epoch: 016/040 | Batch 0200/0230 | Loss: 0.2438
# Epoch: 016/040 | Train ACC: 87.50% | Validation ACC: 79.24%| Train LOSS: 0.5853| Validation LOSS: 0.6096
# Time elapsed: 55.20 min
# Saving intermediate model weights
# Epoch: 017/040 | Batch 0000/0230 | Loss: 0.5011
# Epoch: 017/040 | Batch 0100/0230 | Loss: 0.3191
# Epoch: 017/040 | Batch 0200/0230 | Loss: 0.2856
# Epoch: 017/040 | Train ACC: 90.62% | Validation ACC: 82.10%| Train LOSS: 0.5805| Validation LOSS: 0.5480
# Time elapsed: 56.30 min
# Epoch: 018/040 | Batch 0000/0230 | Loss: 0.5367
# Epoch: 018/040 | Batch 0100/0230 | Loss: 0.8772
# Epoch: 018/040 | Batch 0200/0230 | Loss: 0.3429
# Epoch: 018/040 | Train ACC: 82.29% | Validation ACC: 72.95%| Train LOSS: 0.7624| Validation LOSS: 0.8588
# Early Stopping --- Saving the final model
# Final Model Saved. Training Complete!
# Total Training Time: 57.37 min
# Saving FINAL model weights

# %% [markdown]
# **Test Accuracy and test loss**

# %%
test_acc, test_loss= compute_accuracy_and_loss(model, test_loader,criterion, device=device)
print(f'Test Accuracy {test_acc :.2f}%')
print(f'Test Loss {test_loss :.4f}')
# Out:
# Test Accuracy 74.00%
# Test Loss 0.7784

# %% [markdown]
# **Plot the Training Mini_Batch_loss**

# %%
plot_training_batch_loss(minibatch_loss_list, num_epochs, len(train_loader))
plt.show()

# %% [markdown]
# **Plot train vs Validation Accuracy**

# %%
plot_accuracy(train_acc_list, valid_acc_list)
plt.show()

# %% [markdown]
# **Plot train vs Validation Loss**

# %%
plot_loss(train_loss_list, valid_loss_list)
plt.show()

# %% [markdown]
# **Saving the loss and accuracy into file for later model comparison**

# %%
landuse_dataset_output_dict = {"train_acc_list":train_acc_list,"valid_acc_list":valid_acc_list, "train_loss_list":train_loss_list, "valid_loss_list": valid_loss_list}

import json 

#writing this dict to a file for later use
with open('landuse_dataset_vgg1results.txt', 'w') as f:
    f.write(json.dumps(landuse_dataset_output_dict))


# for reading the file back into a Python object
# with open('./Satellite_dataset_results.txt, 'r') as f:
#     satellite_dataset_output_dict = json.loads(f.read())

# %% [markdown]
# **Confusion Matrix**

# %%
label_encoding = data.class_to_idx

class_dict = {v: k for k, v in label_encoding.items()} #reverse the mapping

print(label_encoding)
# Out:
# {'agricultural': 0, 'airplane': 1, 'baseballdiamond': 2, 'beach': 3, 'buildings': 4, 'chaparral': 5, 'denseresidential': 6, 'forest': 7, 'freeway': 8, 'golfcourse': 9, 'harbor': 10, 'intersection': 11, 'mediumresidential': 12, 'mobilehomepark': 13, 'overpass': 14, 'parkinglot': 15, 'river': 16, 'runway': 17, 'sparseresidential': 18, 'storagetanks': 19, 'tenniscourt': 20}

# %%
# label_encoding = {'cloudy': 0, 'desert': 1, 'green_area': 2, 'water': 3}  # assign to a variable as it will be needed while prediciting

# %%
confusion_matrix = compute_confusion_matrix(model = model, data_loader = test_loader, device=torch.device('cuda:0'))
plot_confusion_matrix(confusion_matrix, class_names = class_dict.values())
plt.show()

# %% [markdown]
# **F1 Score, Precision and Recall**

# %%
print(compute_classification_report(test_loader, model, device=torch.device('cuda') ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86       105
#            1       0.94      0.90      0.92        82
#            2       0.97      0.57      0.72       167
#            3       0.74      0.87      0.80        83
#            4       0.59      0.75      0.66        85
#            5       0.99      0.86      0.92       117
#            6       0.80      0.44      0.56       160
#            7       0.81      0.86      0.83        87
#            8       0.85      0.69      0.77       127
#            9       0.79      0.69      0.74       109
#           10       0.97      0.98      0.98       104
#           11       0.70      0.86      0.77        88
#           12       0.69      0.50      0.58       129
#           13       0.42      1.00      0.59        41
#           14       0.64      0.79      0.71        89
#           15       0.82      0.99      0.90        93
#           16       0.70      0.93      0.80        74
#           17       0.74      0.74      0.74        99
#           18       0.61      0.71      0.66        84
#           19       0.35      0.74      0.48        47
#           20       0.70      0.59      0.64       130
#
#     accuracy                           0.74      2100
#    macro avg       0.75      0.78      0.74      2100
# weighted avg       0.78      0.74      0.75      2100

# %% [markdown]
# **Predicted labels Visualization**

# %%
model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %% [markdown]
# **Load the saved model to make predictions**

# %%
model  = torch.load(path_to_save_model + file_name+'_FINAL_MODEL_WEIGHTS.pth', map_location=torch.device('cpu'))

# %%
# test image path 
img_path = '/content/drive/MyDrive/archive/images_train_test_val/test/baseballdiamond/baseballdiamond_000006.png'

# %%
classes = ['agricultural', 'airplane', 'baseballdiamond', 'beach', 'buildings', 'chaparral', 'denseresidential', 'forest', 'freeway', 'golfcourse', 'harbor', 'intersection', 'mediumresidential', 'mobilehomepark', 'overpass', 'parkinglot', 'river', 'runway', 'sparseresidential', 'storagetanks', 'tenniscourt']
print("The predicted class is " , predict_image_class(model, img_path, classes))
# Out:
# The predicted class is  baseballdiamond
