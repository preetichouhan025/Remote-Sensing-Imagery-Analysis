# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import matplotlib.pyplot as plt 
import numpy as np

# %%
#reading RESNET performance graph 
with open('/content/drive/MyDrive/AI Project/Model Training/Satellite_dataset_results_resnet.txt', 'r') as f:
    Satellite_dataset_results_resnet = json.loads(f.read())

#reading VGG performance graph 
with open('/content/drive/MyDrive/AI Project/Model Training/Satellite_dataset_results_vgg.txt', 'r') as f:
    Satellite_dataset_results_vgg = json.loads(f.read())

#reading ENET performance graph 
with open('/content/drive/MyDrive/AI Project/Model Training/Satellite_dataset_results_enet2.txt', 'r') as f:
    Satellite_dataset_results_enet = json.loads(f.read())

# %%
print(Satellite_dataset_results_resnet[''])

# %% [markdown]
# **Plotting Accuracy of Satellite Dataset with all three models - VGG16, ResNet50 and ENet_b0**

# %%
num_epochs = 40
plt.figure(figsize=(10,8))

#vgg16 model
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_vgg['train_acc_list'], label='VGG16 Training')
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_vgg['valid_acc_list'], label='VGG16 Validation')

# resnet50 Model
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_resnet['train_acc_list']+ [None]*(40-len(Satellite_dataset_results_resnet['train_acc_list'])), label='ResNet50 Training')
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_resnet['valid_acc_list']+ [None]*(40-len(Satellite_dataset_results_resnet['valid_acc_list'])), label='ResNet50 Validation')

#enet_b0
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_enet['train_acc_list'], label='ENet_b0 Training')
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_enet['valid_acc_list'], label='ENet_b0 Validation')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.title("Train VS Validation ACCURACY of Satellite Dataset with VGG16, ResNet50 and Enet_b0")
plt.tight_layout()

# %%
num_epochs = 40
plt.figure(figsize=(10,8))

#vgg16 model
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_vgg['train_loss_list'], label='VGG16 Training')
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_vgg['valid_loss_list'], label='VGG16 Validation')

# resnet50 Model
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_resnet['train_loss_list']+ [None]*(num_epochs-len(Satellite_dataset_results_resnet['train_loss_list'])), label='ResNet50 Training')
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_resnet['valid_loss_list']+ [None]*(num_epochs-len(Satellite_dataset_results_resnet['valid_loss_list'])), label='ResNet50 Validation')

#enet_b0
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_enet['train_loss_list'], label='ENet_b0 Training')
plt.plot(np.arange(1, num_epochs+1),
          Satellite_dataset_results_enet['valid_loss_list'], label='ENet_b0 Validation')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.title("Train VS Validation LOSS of Satellite Dataset with VGG16, ResNet50 and Enet_b0")
plt.tight_layout()
