# %% [markdown]
# <font color = 'Orange' size = 6> Satellite Dataset-RSI-CB256 trained with VGG16 Architecture</font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
helper_methods_folder = '/content/drive/MyDrive/AI Project/Model Training/helper_methods'

sys.path.append(os.path.abspath(helper_methods_folder))

# %% [markdown]
# **Importing helper methods for preprocessing, training and plotting**

# %%
from preprocessing import load_data
from plots import plot_data_loader, show_examples
from plots import plot_accuracy, plot_loss,plot_training_batch_loss, plot_confusion_matrix
from training import train_model, compute_accuracy_and_loss
from early_stopping import EarlyStopping
from metrics import compute_classification_report, compute_confusion_matrix
from unnormalize_images import UnNormalize
from predictions import predict_image_class

# %% [markdown]
# **Importing Libraries**

# %%
from torchvision import models
import torch.nn as nn
import torch
import matplotlib.pyplot as plt

# %%
root_dir = r'/content/drive/MyDrive/AI Project/Datasets/Satellite Dataset-RSI-CB256/data'
path_to_save_model=r"/content/drive/MyDrive/AI Project/Model Training/Satellite_datatset_weights/"
file_name = "satellite_dataset_VGG"

# %% [markdown]
# **Load the datasets into train_loader, validation loader and test loader**

# %%
train_loader, test_loader, valid_loader, data = load_data(root_dir, test_split=0.2, val_split=0.1, batch_size=32, input_size=[64,64])

# %%
# checking the train loader dataset information
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Image batch dimensions: torch.Size([32, 3, 64, 64])
# Image label dimensions: torch.Size([32])
# Class labels of 10 examples: tensor([1, 2, 2, 0, 3, 0, 3, 3, 2, 3])

# %% [markdown]
# **Encodings for the classes**

# %%
label_encoding = data.class_to_idx  
print("label mapping is ", label_encoding)   # save these mapping for predicition
# Out:
# label mapping is  {'cloudy': 0, 'desert': 1, 'green_area': 2, 'water': 3}

# %% [markdown]
# **Plot the data loader**

# %%
plot_data_loader(train_loader, (4,4))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Load VGG16 Model with Batch Normalization**

# %%
model = models.vgg16_bn()  # By default, no pre-trained weights are used.
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# **Change the number of outputs classes in the last layer of the model**

# %%
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, 4)  #num_classes = 4
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=4, bias=True)
#   )
# )

# %% [markdown]
# **Set the hyperparameters**

# %%
# define the loss function for multi-class classifictaion
criterion = nn.CrossEntropyLoss()

# criterion = torch.nn.functional.cross_entropy
#Adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0001)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 3, verbose=False)

# create and early stopping object which will be used during the training
early_stopping = EarlyStopping(tolerance=3, min_delta=0.001)

num_epochs = 40

# %% [markdown]
# **Train the Model with train_loader and perform validation with valid_loader**

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(42)
print("Device: {}".format(device))

model.to(device)

minibatch_loss_list, train_acc_list, valid_acc_list, train_loss_list, valid_loss_list = train_model(
    model=model,
    num_epochs=num_epochs,
    train_loader=train_loader,
    valid_loader=valid_loader,
    criterion = criterion,
    optimizer=optimizer,
    device=device,
    early_stopping=early_stopping,
    file_name = file_name,
    path_to_save_model=path_to_save_model,
    scheduler=scheduler)
# Out:
# Device: cuda:0
# Epoch: 001/040 | Batch 0000/0124 | Loss: 1.4442
# Epoch: 001/040 | Batch 0100/0124 | Loss: 0.7734
# Epoch: 001/040 | Train ACC: 50.00% | Validation ACC: 81.35%| Train LOSS: 1.2042| Validation LOSS: 0.5218
# Time elapsed: 27.05 min
# Epoch: 002/040 | Batch 0000/0124 | Loss: 0.5139
# Epoch: 002/040 | Batch 0100/0124 | Loss: 0.5631
# Epoch: 002/040 | Train ACC: 81.25% | Validation ACC: 84.55%| Train LOSS: 0.6433| Validation LOSS: 0.4437
# Time elapsed: 27.47 min
# Epoch: 003/040 | Batch 0000/0124 | Loss: 0.4820
# Epoch: 003/040 | Batch 0100/0124 | Loss: 0.3648
# Epoch: 003/040 | Train ACC: 82.81% | Validation ACC: 89.70%| Train LOSS: 0.4465| Validation LOSS: 0.2845
# Time elapsed: 27.89 min
# Epoch: 004/040 | Batch 0000/0124 | Loss: 0.5245
# Epoch: 004/040 | Batch 0100/0124 | Loss: 0.7669
# Epoch: 004/040 | Train ACC: 81.25% | Validation ACC: 91.12%| Train LOSS: 0.4146| Validation LOSS: 0.2806
# Time elapsed: 28.31 min
# Epoch: 005/040 | Batch 0000/0124 | Loss: 0.3687
# Epoch: 005/040 | Batch 0100/0124 | Loss: 0.1935
# Epoch: 005/040 | Train ACC: 85.94% | Validation ACC: 90.41%| Train LOSS: 0.4016| Validation LOSS: 0.2493
# Time elapsed: 28.73 min
# Epoch: 006/040 | Batch 0000/0124 | Loss: 0.4461
# Epoch: 006/040 | Batch 0100/0124 | Loss: 0.3114
# Epoch: 006/040 | Train ACC: 87.50% | Validation ACC: 88.81%| Train LOSS: 0.4954| Validation LOSS: 0.3357
# Time elapsed: 29.15 min
# Epoch: 007/040 | Batch 0000/0124 | Loss: 0.2195
# Epoch: 007/040 | Batch 0100/0124 | Loss: 0.3811
# Epoch: 007/040 | Train ACC: 90.62% | Validation ACC: 91.83%| Train LOSS: 0.5894| Validation LOSS: 0.2519
# Time elapsed: 29.57 min
# Epoch: 008/040 | Batch 0000/0124 | Loss: 0.4967
# Epoch: 008/040 | Batch 0100/0124 | Loss: 0.3724
# Epoch: 008/040 | Train ACC: 87.50% | Validation ACC: 89.88%| Train LOSS: 0.4207| Validation LOSS: 0.3171
# Time elapsed: 29.99 min
# Saving intermediate model weights
# Epoch: 009/040 | Batch 0000/0124 | Loss: 0.7421
# Epoch: 009/040 | Batch 0100/0124 | Loss: 0.2474
# Epoch: 009/040 | Train ACC: 84.38% | Validation ACC: 93.43%| Train LOSS: 0.3192| Validation LOSS: 0.2004
# Time elapsed: 30.47 min
# Epoch: 010/040 | Batch 0000/0124 | Loss: 0.1071
# Epoch: 010/040 | Batch 0100/0124 | Loss: 0.0967
# Epoch: 010/040 | Train ACC: 98.44% | Validation ACC: 93.78%| Train LOSS: 0.2560| Validation LOSS: 0.1843
# Time elapsed: 30.89 min
# Epoch: 011/040 | Batch 0000/0124 | Loss: 0.2165
# Epoch: 011/040 | Batch 0100/0124 | Loss: 0.1450
# Epoch: 011/040 | Train ACC: 95.31% | Validation ACC: 95.20%| Train LOSS: 0.2599| Validation LOSS: 0.1642
# Time elapsed: 31.32 min
# Epoch: 012/040 | Batch 0000/0124 | Loss: 0.3039
# Epoch: 012/040 | Batch 0100/0124 | Loss: 0.4422
# Epoch: 012/040 | Train ACC: 89.06% | Validation ACC: 92.01%| Train LOSS: 0.3717| Validation LOSS: 0.2649
# Time elapsed: 31.74 min
# Epoch: 013/040 | Batch 0000/0124 | Loss: 0.4302
# Epoch: 013/040 | Batch 0100/0124 | Loss: 0.9353
# Epoch: 013/040 | Train ACC: 82.81% | Validation ACC: 92.36%| Train LOSS: 0.4022| Validation LOSS: 0.2071
# Time elapsed: 32.16 min
# Epoch: 014/040 | Batch 0000/0124 | Loss: 0.3946
# Epoch: 014/040 | Batch 0100/0124 | Loss: 0.5595
# Epoch: 014/040 | Train ACC: 78.12% | Validation ACC: 92.54%| Train LOSS: 0.3339| Validation LOSS: 0.2545
# Time elapsed: 32.58 min
# Epoch: 015/040 | Batch 0000/0124 | Loss: 0.4069
# Epoch: 015/040 | Batch 0100/0124 | Loss: 0.2991
# Epoch: 015/040 | Train ACC: 90.62% | Validation ACC: 93.78%| Train LOSS: 0.2575| Validation LOSS: 0.1813
# Time elapsed: 32.99 min
# Epoch: 016/040 | Batch 0000/0124 | Loss: 0.1942
# Epoch: 016/040 | Batch 0100/0124 | Loss: 0.0656
# Epoch: 016/040 | Train ACC: 95.31% | Validation ACC: 94.67%| Train LOSS: 0.2116| Validation LOSS: 0.1431
# Time elapsed: 33.41 min
# Saving intermediate model weights
# Epoch: 017/040 | Batch 0000/0124 | Loss: 0.0759
# Epoch: 017/040 | Batch 0100/0124 | Loss: 0.1597
# Epoch: 017/040 | Train ACC: 96.88% | Validation ACC: 96.09%| Train LOSS: 0.2401| Validation LOSS: 0.1577
# Time elapsed: 33.89 min
# Epoch: 018/040 | Batch 0000/0124 | Loss: 0.2405
# Epoch: 018/040 | Batch 0100/0124 | Loss: 0.3078
# Epoch: 018/040 | Train ACC: 92.19% | Validation ACC: 91.47%| Train LOSS: 0.3543| Validation LOSS: 0.2249
# Time elapsed: 34.31 min
# Epoch: 019/040 | Batch 0000/0124 | Loss: 0.1502
# Epoch: 019/040 | Batch 0100/0124 | Loss: 0.2817
# Epoch: 019/040 | Train ACC: 93.75% | Validation ACC: 94.67%| Train LOSS: 0.3432| Validation LOSS: 0.2032
# Time elapsed: 34.73 min
# Epoch: 020/040 | Batch 0000/0124 | Loss: 0.4626
# Epoch: 020/040 | Batch 0100/0124 | Loss: 0.2834
# Epoch: 020/040 | Train ACC: 85.94% | Validation ACC: 92.90%| Train LOSS: 0.2637| Validation LOSS: 0.2259
# Time elapsed: 35.15 min
# Epoch: 021/040 | Batch 0000/0124 | Loss: 0.0762
# Epoch: 021/040 | Batch 0100/0124 | Loss: 0.0978
# Epoch: 021/040 | Train ACC: 98.44% | Validation ACC: 96.98%| Train LOSS: 0.1815| Validation LOSS: 0.1018
# Time elapsed: 35.57 min
# Epoch: 022/040 | Batch 0000/0124 | Loss: 0.2005
# Epoch: 022/040 | Batch 0100/0124 | Loss: 0.3435
# Epoch: 022/040 | Train ACC: 93.75% | Validation ACC: 96.45%| Train LOSS: 0.1895| Validation LOSS: 0.1021
# Time elapsed: 35.99 min
# Epoch: 023/040 | Batch 0000/0124 | Loss: 0.2294
# Epoch: 023/040 | Batch 0100/0124 | Loss: 0.0969
# Epoch: 023/040 | Train ACC: 96.88% | Validation ACC: 96.45%| Train LOSS: 0.2118| Validation LOSS: 0.1255
# Time elapsed: 36.42 min
# Epoch: 024/040 | Batch 0000/0124 | Loss: 0.0524
# Epoch: 024/040 | Batch 0100/0124 | Loss: 0.2154
# Epoch: 024/040 | Train ACC: 95.31% | Validation ACC: 94.32%| Train LOSS: 0.2900| Validation LOSS: 0.1692
# Time elapsed: 36.84 min
# Saving intermediate model weights
# Epoch: 025/040 | Batch 0000/0124 | Loss: 0.1270
# Epoch: 025/040 | Batch 0100/0124 | Loss: 0.3527
# Epoch: 025/040 | Train ACC: 90.62% | Validation ACC: 93.61%| Train LOSS: 0.3154| Validation LOSS: 0.1946
# Time elapsed: 37.31 min
# Epoch: 026/040 | Batch 0000/0124 | Loss: 0.1571
# Epoch: 026/040 | Batch 0100/0124 | Loss: 0.4796
# Epoch: 026/040 | Train ACC: 92.19% | Validation ACC: 94.67%| Train LOSS: 0.2819| Validation LOSS: 0.1383
# Time elapsed: 37.73 min
# Epoch: 027/040 | Batch 0000/0124 | Loss: 0.2859
# Epoch: 027/040 | Batch 0100/0124 | Loss: 0.1504
# Epoch: 027/040 | Train ACC: 92.19% | Validation ACC: 96.27%| Train LOSS: 0.2015| Validation LOSS: 0.1044
# Time elapsed: 38.15 min
# Epoch: 028/040 | Batch 0000/0124 | Loss: 0.4640
# Epoch: 028/040 | Batch 0100/0124 | Loss: 0.0817
# Epoch: 028/040 | Train ACC: 90.62% | Validation ACC: 97.16%| Train LOSS: 0.1626| Validation LOSS: 0.0944
# Time elapsed: 38.57 min
# Epoch: 029/040 | Batch 0000/0124 | Loss: 0.1743
# Epoch: 029/040 | Batch 0100/0124 | Loss: 0.0780
# Epoch: 029/040 | Train ACC: 96.88% | Validation ACC: 94.85%| Train LOSS: 0.1788| Validation LOSS: 0.1554
# Time elapsed: 38.99 min
# Epoch: 030/040 | Batch 0000/0124 | Loss: 0.0620
# Epoch: 030/040 | Batch 0100/0124 | Loss: 0.2205
# Epoch: 030/040 | Train ACC: 96.88% | Validation ACC: 95.38%| Train LOSS: 0.2384| Validation LOSS: 0.1938
# Time elapsed: 39.41 min
# Epoch: 031/040 | Batch 0000/0124 | Loss: 0.0647
# Epoch: 031/040 | Batch 0100/0124 | Loss: 0.2163
# Epoch: 031/040 | Train ACC: 96.88% | Validation ACC: 92.18%| Train LOSS: 0.3313| Validation LOSS: 0.2383
# Time elapsed: 39.83 min
# Epoch: 032/040 | Batch 0000/0124 | Loss: 0.3556
# Epoch: 032/040 | Batch 0100/0124 | Loss: 0.4784
# Epoch: 032/040 | Train ACC: 90.62% | Validation ACC: 97.16%| Train LOSS: 0.2422| Validation LOSS: 0.1257
# Time elapsed: 40.26 min
# Saving intermediate model weights
# Epoch: 033/040 | Batch 0000/0124 | Loss: 0.1108
# Epoch: 033/040 | Batch 0100/0124 | Loss: 0.2021
# Epoch: 033/040 | Train ACC: 95.31% | Validation ACC: 96.98%| Train LOSS: 0.1421| Validation LOSS: 0.0969
# Time elapsed: 40.75 min
# Epoch: 034/040 | Batch 0000/0124 | Loss: 0.1562
# Epoch: 034/040 | Batch 0100/0124 | Loss: 0.2287
# Epoch: 034/040 | Train ACC: 92.19% | Validation ACC: 97.87%| Train LOSS: 0.1383| Validation LOSS: 0.0775
# Time elapsed: 41.18 min
# Epoch: 035/040 | Batch 0000/0124 | Loss: 0.2334
# Epoch: 035/040 | Batch 0100/0124 | Loss: 0.0531
# Epoch: 035/040 | Train ACC: 96.88% | Validation ACC: 97.51%| Train LOSS: 0.1423| Validation LOSS: 0.0830
# Time elapsed: 41.61 min
# Epoch: 036/040 | Batch 0000/0124 | Loss: 0.0619
# Epoch: 036/040 | Batch 0100/0124 | Loss: 0.1436
# Epoch: 036/040 | Train ACC: 96.88% | Validation ACC: 95.20%| Train LOSS: 0.2101| Validation LOSS: 0.1502
# Time elapsed: 42.04 min
# Epoch: 037/040 | Batch 0000/0124 | Loss: 0.0965
# Epoch: 037/040 | Batch 0100/0124 | Loss: 0.1758
# Epoch: 037/040 | Train ACC: 95.31% | Validation ACC: 95.20%| Train LOSS: 0.3130| Validation LOSS: 0.1846
# Time elapsed: 42.46 min
# Epoch: 038/040 | Batch 0000/0124 | Loss: 0.1808
# Epoch: 038/040 | Batch 0100/0124 | Loss: 0.1804
# Epoch: 038/040 | Train ACC: 90.62% | Validation ACC: 96.80%| Train LOSS: 0.2500| Validation LOSS: 0.1368
# Time elapsed: 42.88 min
# Epoch: 039/040 | Batch 0000/0124 | Loss: 0.2231
# Epoch: 039/040 | Batch 0100/0124 | Loss: 0.0825
# Epoch: 039/040 | Train ACC: 92.19% | Validation ACC: 96.98%| Train LOSS: 0.1570| Validation LOSS: 0.0829
# Time elapsed: 43.29 min
# Epoch: 040/040 | Batch 0000/0124 | Loss: 0.1659
# Epoch: 040/040 | Batch 0100/0124 | Loss: 0.4471
# Epoch: 040/040 | Train ACC: 90.62% | Validation ACC: 97.16%| Train LOSS: 0.1284| Validation LOSS: 0.0972
# Time elapsed: 43.71 min
# Saving intermediate model weights
# Total Training Time: 43.75 min
# Saving FINAL model weights

# %% [markdown]
# **Test Accuracy and test loss**

# %%
test_acc, test_loss= compute_accuracy_and_loss(model, test_loader,criterion, device=device)
print(f'Test Accuracy {test_acc :.2f}%')
print(f'Test Loss {test_loss :.4f}')
# Out:
# Test Accuracy 96.63%
# Test Loss 0.0977

# %% [markdown]
# **Plot the Training Mini_Batch_loss**

# %%
plot_training_batch_loss(minibatch_loss_list, num_epochs, len(train_loader))
plt.show()

# %% [markdown]
# **Plot train vs Validation Accuracy**

# %%
plot_accuracy(train_acc_list, valid_acc_list)
plt.show()

# %% [markdown]
# **Plot train vs Validation Loss**

# %%
plot_loss(train_loss_list, valid_loss_list)
plt.show()

# %% [markdown]
# **Saving the loss and accuracy into file for later model comparison**

# %%
satellite_dataset_output_dict = {"train_acc_list":train_acc_list,"valid_acc_list":valid_acc_list, "train_loss_list":train_loss_list, "valid_loss_list": valid_loss_list}

import json 

#writing this dict to a file for later use
with open('/content/drive/MyDrive/AI Project/Model Training/Satellite_dataset_results_vgg.txt', 'w') as f:
    f.write(json.dumps(satellite_dataset_output_dict))

# %% [markdown]
# **Confusion Matrix**

# %%
label_encoding = data.class_to_idx

class_dict = {v: k for k, v in label_encoding.items()} #reverse the mapping

print(label_encoding)
# Out:
# {'cloudy': 0, 'desert': 1, 'green_area': 2, 'water': 3}

# %%
# label_encoding = {'cloudy': 0, 'desert': 1, 'green_area': 2, 'water': 3}  # assign to a variable as it will be needed while prediciting

# %%
confusion_matrix = compute_confusion_matrix(model = model, data_loader = test_loader, device=torch.device('cuda'))
plot_confusion_matrix(confusion_matrix, class_names = class_dict.values())
plt.show()

# %% [markdown]
# **F1 Score, Precision and Recall**

# %%
print(compute_classification_report(test_loader, model, device=torch.device('cuda') ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       312
#            1       0.98      0.93      0.96       237
#            2       0.98      0.97      0.97       296
#            3       0.95      0.98      0.97       281
#
#     accuracy                           0.96      1126
#    macro avg       0.97      0.96      0.96      1126
# weighted avg       0.96      0.96      0.96      1126

# %% [markdown]
# **Predicted labels Visualization**

# %%
model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %% [markdown]
# **Load the saved model to make predictions**

# %%
model  = torch.load(path_to_save_model + file_name+'_FINAL_MODEL_WEIGHTS.pth', map_location=torch.device('cpu'))

# %%
# test image path 
img_path = '/content/drive/MyDrive/AI Project/Model Training/test_images/water_body_1014.jpg'

# %%
classes = ['cloudy','desert','green_area','water']
print("The predicted class is " , predict_image_class(model, img_path, classes))
# Out:
# The predicted class is  water
