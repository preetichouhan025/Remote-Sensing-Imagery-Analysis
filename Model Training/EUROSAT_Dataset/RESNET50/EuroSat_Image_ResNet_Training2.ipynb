# %% [markdown]
# <font color = 'Orange' size = 6> EuroSat trained with ResNet50 Architecture</font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
helper_methods_folder = '/content/drive/MyDrive/AI Project/Model Training/helper_methods'

sys.path.append(os.path.abspath(helper_methods_folder))

# %% [markdown]
# **Importing helper methods for preprocessing, training and plotting**

# %%
from preprocessing import load_data
from plots import plot_data_loader, show_examples
from plots import plot_accuracy, plot_loss,plot_training_batch_loss, plot_confusion_matrix
from training import train_model, compute_accuracy_and_loss
from early_stopping import EarlyStopping
from metrics import compute_classification_report, compute_confusion_matrix
from unnormalize_images import UnNormalize
from predictions import predict_image_class

# %% [markdown]
# **Importing Libraries**

# %%
from torchvision import models
import torch.nn as nn
import torch
import matplotlib.pyplot as plt

# %%
root_dir = r'/content/drive/MyDrive/AI Project/Datasets/EuroSAT'
path_to_save_model=r"/content/drive/MyDrive/AI Project/Model Training/EuroSat_datatset_weights/"
file_name = "EuroSat_dataset_ResNet"

# %% [markdown]
# **Load the datasets into train_loader, validation loader and test loader**

# %%
train_loader, test_loader, valid_loader, data = load_data(root_dir, test_split=0.2, val_split=0.1, batch_size=32, input_size=[64,64])

# %%
# checking the train loader dataset information
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Image batch dimensions: torch.Size([32, 3, 64, 64])
# Image label dimensions: torch.Size([32])
# Class labels of 10 examples: tensor([3, 2, 7, 2, 3, 3, 3, 1, 6, 2])

# %% [markdown]
# **Encodings for the classes**

# %%
label_encoding = data.class_to_idx  
print("label mapping is ", label_encoding)   # save these mapping for predicition
# Out:
# label mapping is  {'AnnualCrop': 0, 'Forest': 1, 'HerbaceousVegetation': 2, 'Highway': 3, 'Industrial': 4, 'Pasture': 5, 'PermanentCrop': 6, 'Residential': 7, 'River': 8, 'SeaLake': 9}

# %% [markdown]
# **Plot the data loader**

# %%
plot_data_loader(train_loader, (4,4))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Load ResNet50 Model**

# %%
model = models.resnet50(pretrained=False)  # By default, no pre-trained weights are used.
print(model)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %% [markdown]
# **Change the number of outputs classes in the last layer of the model**

# %%
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 10)  #num_classes = 10
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %% [markdown]
# **Set the hyperparameters**

# %%
# define the loss function for multi-class classifictaion
criterion = nn.CrossEntropyLoss()

# criterion = torch.nn.functional.cross_entropy
#Adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0001)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 3, verbose=False)

# create and early stopping object which will be used during the training
early_stopping = EarlyStopping(tolerance=3, min_delta=0.001)

num_epochs = 40

# %% [markdown]
# **Train the Model with train_loader and perform validation with valid_loader**

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# torch.manual_seed(42)
print("Device: {}".format(device))

model.to(device)

minibatch_loss_list, train_acc_list, valid_acc_list, train_loss_list, valid_loss_list = train_model(
    model=model,
    num_epochs=num_epochs,
    train_loader=train_loader,
    valid_loader=valid_loader,
    criterion = criterion,
    optimizer=optimizer,
    device=device,
    early_stopping=early_stopping,
    file_name = file_name,
    path_to_save_model=path_to_save_model,
    scheduler=scheduler)
# Out:
# Device: cuda:0
# Epoch: 001/040 | Batch 0000/0591 | Loss: 2.3971
# Epoch: 001/040 | Batch 0100/0591 | Loss: 2.0998
# Epoch: 001/040 | Batch 0200/0591 | Loss: 1.8367
# Epoch: 001/040 | Batch 0300/0591 | Loss: 1.6813
# Epoch: 001/040 | Batch 0400/0591 | Loss: 1.4761
# Epoch: 001/040 | Batch 0500/0591 | Loss: 1.0418
# Epoch: 001/040 | Train ACC: 39.58% | Validation ACC: 53.41%| Train LOSS: 1.7549| Validation LOSS: 1.3598
# Time elapsed: 92.44 min
# Epoch: 002/040 | Batch 0000/0591 | Loss: 1.3206
# Epoch: 002/040 | Batch 0100/0591 | Loss: 1.3676
# Epoch: 002/040 | Batch 0200/0591 | Loss: 1.2781
# Epoch: 002/040 | Batch 0300/0591 | Loss: 1.5021
# Epoch: 002/040 | Batch 0400/0591 | Loss: 1.4041
# Epoch: 002/040 | Batch 0500/0591 | Loss: 1.2700
# Epoch: 002/040 | Train ACC: 50.52% | Validation ACC: 60.63%| Train LOSS: 1.2560| Validation LOSS: 1.1150
# Time elapsed: 93.67 min
# Epoch: 003/040 | Batch 0000/0591 | Loss: 1.3163
# Epoch: 003/040 | Batch 0100/0591 | Loss: 1.0895
# Epoch: 003/040 | Batch 0200/0591 | Loss: 0.9278
# Epoch: 003/040 | Batch 0300/0591 | Loss: 0.8942
# Epoch: 003/040 | Batch 0400/0591 | Loss: 1.3225
# Epoch: 003/040 | Batch 0500/0591 | Loss: 1.0946
# Epoch: 003/040 | Train ACC: 61.46% | Validation ACC: 64.70%| Train LOSS: 1.0687| Validation LOSS: 0.9474
# Time elapsed: 94.85 min
# Epoch: 004/040 | Batch 0000/0591 | Loss: 0.7733
# Epoch: 004/040 | Batch 0100/0591 | Loss: 1.2458
# Epoch: 004/040 | Batch 0200/0591 | Loss: 1.0120
# Epoch: 004/040 | Batch 0300/0591 | Loss: 1.0565
# Epoch: 004/040 | Batch 0400/0591 | Loss: 0.8509
# Epoch: 004/040 | Batch 0500/0591 | Loss: 1.1974
# Epoch: 004/040 | Train ACC: 64.06% | Validation ACC: 64.96%| Train LOSS: 1.0492| Validation LOSS: 0.9570
# Time elapsed: 96.04 min
# Epoch: 005/040 | Batch 0000/0591 | Loss: 0.8785
# Epoch: 005/040 | Batch 0100/0591 | Loss: 0.9349
# Epoch: 005/040 | Batch 0200/0591 | Loss: 0.9262
# Epoch: 005/040 | Batch 0300/0591 | Loss: 1.0246
# Epoch: 005/040 | Batch 0400/0591 | Loss: 0.8234
# Epoch: 005/040 | Batch 0500/0591 | Loss: 0.9006
# Epoch: 005/040 | Train ACC: 66.15% | Validation ACC: 67.70%| Train LOSS: 1.0270| Validation LOSS: 0.9191
# Time elapsed: 97.26 min
# Epoch: 006/040 | Batch 0000/0591 | Loss: 1.0180
# Epoch: 006/040 | Batch 0100/0591 | Loss: 1.3018
# Epoch: 006/040 | Batch 0200/0591 | Loss: 0.9770
# Epoch: 006/040 | Batch 0300/0591 | Loss: 1.2075
# Epoch: 006/040 | Batch 0400/0591 | Loss: 1.2198
# Epoch: 006/040 | Batch 0500/0591 | Loss: 0.7586
# Epoch: 006/040 | Train ACC: 61.46% | Validation ACC: 64.63%| Train LOSS: 1.0689| Validation LOSS: 0.9620
# Time elapsed: 98.45 min
# Epoch: 007/040 | Batch 0000/0591 | Loss: 1.3451
# Epoch: 007/040 | Batch 0100/0591 | Loss: 1.1339
# Epoch: 007/040 | Batch 0200/0591 | Loss: 1.1974
# Epoch: 007/040 | Batch 0300/0591 | Loss: 1.3110
# Epoch: 007/040 | Batch 0400/0591 | Loss: 0.7219
# Epoch: 007/040 | Batch 0500/0591 | Loss: 1.4123
# Epoch: 007/040 | Train ACC: 56.25% | Validation ACC: 68.44%| Train LOSS: 1.0194| Validation LOSS: 0.8812
# Time elapsed: 99.63 min
# Epoch: 008/040 | Batch 0000/0591 | Loss: 0.8593
# Epoch: 008/040 | Batch 0100/0591 | Loss: 0.8624
# Epoch: 008/040 | Batch 0200/0591 | Loss: 0.6885
# Epoch: 008/040 | Batch 0300/0591 | Loss: 0.6586
# Epoch: 008/040 | Batch 0400/0591 | Loss: 0.6527
# Epoch: 008/040 | Batch 0500/0591 | Loss: 1.1247
# Epoch: 008/040 | Train ACC: 74.48% | Validation ACC: 71.70%| Train LOSS: 0.9308| Validation LOSS: 0.7932
# Time elapsed: 100.84 min
# Saving intermediate model weights
# Epoch: 009/040 | Batch 0000/0591 | Loss: 0.5704
# Epoch: 009/040 | Batch 0100/0591 | Loss: 0.9522
# Epoch: 009/040 | Batch 0200/0591 | Loss: 0.7595
# Epoch: 009/040 | Batch 0300/0591 | Loss: 1.2053
# Epoch: 009/040 | Batch 0400/0591 | Loss: 0.6537
# Epoch: 009/040 | Batch 0500/0591 | Loss: 0.9074
# Epoch: 009/040 | Train ACC: 68.23% | Validation ACC: 74.15%| Train LOSS: 0.8204| Validation LOSS: 0.7102
# Time elapsed: 102.04 min
# Epoch: 010/040 | Batch 0000/0591 | Loss: 0.8560
# Epoch: 010/040 | Batch 0100/0591 | Loss: 0.7444
# Epoch: 010/040 | Batch 0200/0591 | Loss: 0.7631
# Epoch: 010/040 | Batch 0300/0591 | Loss: 1.0402
# Epoch: 010/040 | Batch 0400/0591 | Loss: 0.5610
# Epoch: 010/040 | Batch 0500/0591 | Loss: 0.6891
# Epoch: 010/040 | Train ACC: 70.31% | Validation ACC: 73.67%| Train LOSS: 0.7889| Validation LOSS: 0.7159
# Time elapsed: 103.22 min
# Epoch: 011/040 | Batch 0000/0591 | Loss: 0.8838
# Epoch: 011/040 | Batch 0100/0591 | Loss: 0.9420
# Epoch: 011/040 | Batch 0200/0591 | Loss: 0.6042
# Epoch: 011/040 | Batch 0300/0591 | Loss: 0.6578
# Epoch: 011/040 | Batch 0400/0591 | Loss: 0.8665
# Epoch: 011/040 | Batch 0500/0591 | Loss: 0.6415
# Epoch: 011/040 | Train ACC: 69.27% | Validation ACC: 72.63%| Train LOSS: 0.7956| Validation LOSS: 0.7483
# Time elapsed: 104.44 min
# Epoch: 012/040 | Batch 0000/0591 | Loss: 0.9836
# Epoch: 012/040 | Batch 0100/0591 | Loss: 1.2503
# Epoch: 012/040 | Batch 0200/0591 | Loss: 0.5688
# Epoch: 012/040 | Batch 0300/0591 | Loss: 0.7982
# Epoch: 012/040 | Batch 0400/0591 | Loss: 0.6324
# Epoch: 012/040 | Batch 0500/0591 | Loss: 0.8983
# Epoch: 012/040 | Train ACC: 64.58% | Validation ACC: 71.85%| Train LOSS: 0.8759| Validation LOSS: 0.7984
# Time elapsed: 105.61 min
# Epoch: 013/040 | Batch 0000/0591 | Loss: 0.9578
# Epoch: 013/040 | Batch 0100/0591 | Loss: 0.8807
# Epoch: 013/040 | Batch 0200/0591 | Loss: 1.1159
# Epoch: 013/040 | Batch 0300/0591 | Loss: 0.7646
# Epoch: 013/040 | Batch 0400/0591 | Loss: 0.8462
# Epoch: 013/040 | Batch 0500/0591 | Loss: 0.8046
# Epoch: 013/040 | Train ACC: 70.31% | Validation ACC: 72.04%| Train LOSS: 0.8653| Validation LOSS: 0.7823
# Time elapsed: 106.79 min
# Epoch: 014/040 | Batch 0000/0591 | Loss: 0.9296
# Epoch: 014/040 | Batch 0100/0591 | Loss: 0.9177
# Epoch: 014/040 | Batch 0200/0591 | Loss: 0.9832
# Epoch: 014/040 | Batch 0300/0591 | Loss: 0.6763
# Epoch: 014/040 | Batch 0400/0591 | Loss: 0.7495
# Epoch: 014/040 | Batch 0500/0591 | Loss: 0.7006
# Epoch: 014/040 | Train ACC: 70.31% | Validation ACC: 73.70%| Train LOSS: 0.7808| Validation LOSS: 0.7426
# Time elapsed: 108.01 min
# Epoch: 015/040 | Batch 0000/0591 | Loss: 0.7285
# Epoch: 015/040 | Batch 0100/0591 | Loss: 0.8797
# Epoch: 015/040 | Batch 0200/0591 | Loss: 0.5540
# Epoch: 015/040 | Batch 0300/0591 | Loss: 0.5248
# Epoch: 015/040 | Batch 0400/0591 | Loss: 0.6771
# Epoch: 015/040 | Batch 0500/0591 | Loss: 0.6203
# Epoch: 015/040 | Train ACC: 74.48% | Validation ACC: 78.81%| Train LOSS: 0.6688| Validation LOSS: 0.5988
# Time elapsed: 109.19 min
# Epoch: 016/040 | Batch 0000/0591 | Loss: 0.5371
# Epoch: 016/040 | Batch 0100/0591 | Loss: 0.6919
# Epoch: 016/040 | Batch 0200/0591 | Loss: 0.6490
# Epoch: 016/040 | Batch 0300/0591 | Loss: 0.7595
# Epoch: 016/040 | Batch 0400/0591 | Loss: 0.6729
# Epoch: 016/040 | Batch 0500/0591 | Loss: 0.7979
# Epoch: 016/040 | Train ACC: 75.52% | Validation ACC: 78.33%| Train LOSS: 0.6403| Validation LOSS: 0.5968
# Time elapsed: 110.37 min
# Saving intermediate model weights
# Epoch: 017/040 | Batch 0000/0591 | Loss: 0.6330
# Epoch: 017/040 | Batch 0100/0591 | Loss: 1.2705
# Epoch: 017/040 | Batch 0200/0591 | Loss: 0.8148
# Epoch: 017/040 | Batch 0300/0591 | Loss: 0.7249
# Epoch: 017/040 | Batch 0400/0591 | Loss: 0.5616
# Epoch: 017/040 | Batch 0500/0591 | Loss: 0.6095
# Epoch: 017/040 | Train ACC: 73.44% | Validation ACC: 76.52%| Train LOSS: 0.6380| Validation LOSS: 0.6530
# Time elapsed: 111.58 min
# Epoch: 018/040 | Batch 0000/0591 | Loss: 0.4536
# Epoch: 018/040 | Batch 0100/0591 | Loss: 0.6835
# Epoch: 018/040 | Batch 0200/0591 | Loss: 0.6428
# Epoch: 018/040 | Batch 0300/0591 | Loss: 0.5585
# Epoch: 018/040 | Batch 0400/0591 | Loss: 0.4574
# Epoch: 018/040 | Batch 0500/0591 | Loss: 0.8731
# Epoch: 018/040 | Train ACC: 73.96% | Validation ACC: 76.41%| Train LOSS: 0.7173| Validation LOSS: 0.6485
# Time elapsed: 112.75 min
# Epoch: 019/040 | Batch 0000/0591 | Loss: 0.6142
# Epoch: 019/040 | Batch 0100/0591 | Loss: 0.9746
# Epoch: 019/040 | Batch 0200/0591 | Loss: 0.9156
# Epoch: 019/040 | Batch 0300/0591 | Loss: 0.8405
# Epoch: 019/040 | Batch 0400/0591 | Loss: 0.7470
# Epoch: 019/040 | Batch 0500/0591 | Loss: 0.4466
# Epoch: 019/040 | Train ACC: 75.52% | Validation ACC: 75.00%| Train LOSS: 0.7106| Validation LOSS: 0.7066
# Time elapsed: 113.93 min
# Epoch: 020/040 | Batch 0000/0591 | Loss: 0.7563
# Epoch: 020/040 | Batch 0100/0591 | Loss: 0.5891
# Epoch: 020/040 | Batch 0200/0591 | Loss: 0.9611
# Epoch: 020/040 | Batch 0300/0591 | Loss: 0.6590
# Epoch: 020/040 | Batch 0400/0591 | Loss: 0.5697
# Epoch: 020/040 | Batch 0500/0591 | Loss: 0.4610
# Epoch: 020/040 | Train ACC: 74.48% | Validation ACC: 78.22%| Train LOSS: 0.6459| Validation LOSS: 0.5911
# Time elapsed: 115.14 min
# Epoch: 021/040 | Batch 0000/0591 | Loss: 0.5311
# Epoch: 021/040 | Batch 0100/0591 | Loss: 0.8036
# Epoch: 021/040 | Batch 0200/0591 | Loss: 0.7503
# Epoch: 021/040 | Batch 0300/0591 | Loss: 0.8369
# Epoch: 021/040 | Batch 0400/0591 | Loss: 0.3141
# Epoch: 021/040 | Batch 0500/0591 | Loss: 0.7172
# Epoch: 021/040 | Train ACC: 76.04% | Validation ACC: 82.30%| Train LOSS: 0.5339| Validation LOSS: 0.4937
# Time elapsed: 116.31 min
# Epoch: 022/040 | Batch 0000/0591 | Loss: 0.6117
# Epoch: 022/040 | Batch 0100/0591 | Loss: 0.6611
# Epoch: 022/040 | Batch 0200/0591 | Loss: 0.4512
# Epoch: 022/040 | Batch 0300/0591 | Loss: 0.5859
# Epoch: 022/040 | Batch 0400/0591 | Loss: 0.8442
# Epoch: 022/040 | Batch 0500/0591 | Loss: 0.2818
# Epoch: 022/040 | Train ACC: 81.77% | Validation ACC: 82.63%| Train LOSS: 0.5123| Validation LOSS: 0.4898
# Time elapsed: 117.50 min
# Epoch: 023/040 | Batch 0000/0591 | Loss: 0.4704
# Epoch: 023/040 | Batch 0100/0591 | Loss: 0.4505
# Epoch: 023/040 | Batch 0200/0591 | Loss: 0.7455
# Epoch: 023/040 | Batch 0300/0591 | Loss: 0.6002
# Epoch: 023/040 | Batch 0400/0591 | Loss: 0.6526
# Epoch: 023/040 | Batch 0500/0591 | Loss: 0.5150
# Epoch: 023/040 | Train ACC: 80.73% | Validation ACC: 83.00%| Train LOSS: 0.5189| Validation LOSS: 0.4778
# Time elapsed: 118.69 min
# Epoch: 024/040 | Batch 0000/0591 | Loss: 0.5046
# Epoch: 024/040 | Batch 0100/0591 | Loss: 0.4369
# Epoch: 024/040 | Batch 0200/0591 | Loss: 0.8642
# Epoch: 024/040 | Batch 0300/0591 | Loss: 0.4239
# Epoch: 024/040 | Batch 0400/0591 | Loss: 0.4591
# Epoch: 024/040 | Batch 0500/0591 | Loss: 0.3540
# Epoch: 024/040 | Train ACC: 81.25% | Validation ACC: 75.85%| Train LOSS: 0.5976| Validation LOSS: 0.7111
# Time elapsed: 119.86 min
# Saving intermediate model weights
# Epoch: 025/040 | Batch 0000/0591 | Loss: 0.6119
# Epoch: 025/040 | Batch 0100/0591 | Loss: 0.5674
# Epoch: 025/040 | Batch 0200/0591 | Loss: 0.7704
# Epoch: 025/040 | Batch 0300/0591 | Loss: 0.3750
# Epoch: 025/040 | Batch 0400/0591 | Loss: 0.5936
# Epoch: 025/040 | Batch 0500/0591 | Loss: 0.3946
# Epoch: 025/040 | Train ACC: 82.81% | Validation ACC: 77.26%| Train LOSS: 0.6208| Validation LOSS: 0.6505
# Time elapsed: 121.06 min
# Epoch: 026/040 | Batch 0000/0591 | Loss: 0.6319
# Epoch: 026/040 | Batch 0100/0591 | Loss: 0.7405
# Epoch: 026/040 | Batch 0200/0591 | Loss: 0.5759
# Epoch: 026/040 | Batch 0300/0591 | Loss: 0.4458
# Epoch: 026/040 | Batch 0400/0591 | Loss: 0.2459
# Epoch: 026/040 | Batch 0500/0591 | Loss: 0.5061
# Epoch: 026/040 | Train ACC: 80.21% | Validation ACC: 79.26%| Train LOSS: 0.5425| Validation LOSS: 0.5994
# Time elapsed: 122.23 min
# Epoch: 027/040 | Batch 0000/0591 | Loss: 0.3251
# Epoch: 027/040 | Batch 0100/0591 | Loss: 0.6013
# Epoch: 027/040 | Batch 0200/0591 | Loss: 0.7276
# Epoch: 027/040 | Batch 0300/0591 | Loss: 0.2987
# Epoch: 027/040 | Batch 0400/0591 | Loss: 0.2586
# Epoch: 027/040 | Batch 0500/0591 | Loss: 0.4274
# Epoch: 027/040 | Train ACC: 83.85% | Validation ACC: 85.44%| Train LOSS: 0.4368| Validation LOSS: 0.4147
# Time elapsed: 123.44 min
# Epoch: 028/040 | Batch 0000/0591 | Loss: 0.3614
# Epoch: 028/040 | Batch 0100/0591 | Loss: 0.4703
# Epoch: 028/040 | Batch 0200/0591 | Loss: 0.3910
# Epoch: 028/040 | Batch 0300/0591 | Loss: 0.2696
# Epoch: 028/040 | Batch 0400/0591 | Loss: 0.2903
# Epoch: 028/040 | Batch 0500/0591 | Loss: 0.4832
# Epoch: 028/040 | Train ACC: 85.94% | Validation ACC: 85.63%| Train LOSS: 0.4245| Validation LOSS: 0.4202
# Time elapsed: 124.61 min
# Epoch: 029/040 | Batch 0000/0591 | Loss: 0.5945
# Epoch: 029/040 | Batch 0100/0591 | Loss: 0.5612
# Epoch: 029/040 | Batch 0200/0591 | Loss: 0.3290
# Epoch: 029/040 | Batch 0300/0591 | Loss: 0.6269
# Epoch: 029/040 | Batch 0400/0591 | Loss: 0.4503
# Epoch: 029/040 | Batch 0500/0591 | Loss: 0.4250
# Epoch: 029/040 | Train ACC: 84.90% | Validation ACC: 85.33%| Train LOSS: 0.4151| Validation LOSS: 0.4189
# Early Stopping --- Saving the final model
# Final Model Saved. Training Complete!
# Total Training Time: 125.78 min
# Saving FINAL model weights

# %% [markdown]
# **Test Accuracy and test loss**

# %%
test_acc, test_loss= compute_accuracy_and_loss(model, test_loader,criterion, device=device)
print(f'Test Accuracy {test_acc :.2f}%')
print(f'Test Loss {test_loss :.4f}')
# Out:
# Test Accuracy 85.44%
# Test Loss 0.4094

# %% [markdown]
# **Plot the Training Mini_Batch_loss**

# %%
plot_training_batch_loss(minibatch_loss_list, num_epochs, len(train_loader))
plt.show()

# %% [markdown]
# **Plot train vs Validation Accuracy**

# %%
plot_accuracy(train_acc_list, valid_acc_list)
plt.show()

# %% [markdown]
# **Plot train vs Validation Loss**

# %%
plot_loss(train_loss_list, valid_loss_list)
plt.show()

# %% [markdown]
# **Saving the loss and accuracy into file for later model comparison**

# %%
satellite_dataset_output_dict = {"train_acc_list":train_acc_list,"valid_acc_list":valid_acc_list, "train_loss_list":train_loss_list, "valid_loss_list": valid_loss_list}

import json 

#writing this dict to a file for later use
with open('/content/drive/MyDrive/AI Project/Model Training/EuroSat_dataset_results_ResNet.txt', 'w') as f:
    f.write(json.dumps(satellite_dataset_output_dict))

# %% [markdown]
# **Confusion Matrix**

# %%
label_encoding = data.class_to_idx

class_dict = {v: k for k, v in label_encoding.items()} #reverse the mapping

print(label_encoding)
# Out:
# {'AnnualCrop': 0, 'Forest': 1, 'HerbaceousVegetation': 2, 'Highway': 3, 'Industrial': 4, 'Pasture': 5, 'PermanentCrop': 6, 'Residential': 7, 'River': 8, 'SeaLake': 9}

# %%
# label_encoding = {'cloudy': 0, 'desert': 1, 'green_area': 2, 'water': 3}  # assign to a variable as it will be needed while prediciting

# %%
confusion_matrix = compute_confusion_matrix(model = model, data_loader = test_loader, device=torch.device('cuda'))
plot_confusion_matrix(confusion_matrix, class_names = class_dict.values())
plt.show()

# %% [markdown]
# **F1 Score, Precision and Recall**

# %%
print(compute_classification_report(test_loader, model, device=torch.device('cuda') ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85       578
#            1       0.93      0.91      0.92       600
#            2       0.77      0.79      0.78       636
#            3       0.77      0.76      0.76       469
#            4       0.93      0.89      0.91       515
#            5       0.78      0.85      0.81       369
#            6       0.67      0.73      0.70       467
#            7       0.96      0.89      0.93       684
#            8       0.82      0.87      0.84       464
#            9       0.97      0.94      0.95       618
#
#     accuracy                           0.85      5400
#    macro avg       0.84      0.85      0.84      5400
# weighted avg       0.85      0.85      0.85      5400

# %% [markdown]
# **Predicted labels Visualization**

# %%
model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %% [markdown]
# **Load the saved model to make predictions**

# %%
model  = torch.load(path_to_save_model + file_name+'_FINAL_MODEL_WEIGHTS.pth', map_location=torch.device('cpu'))

# %%
# test image path 
img_path = '/content/drive/MyDrive/AI Project/Model Training/test_images/water_body_1014.jpg'

# %%
classes = ['cloudy','desert','green_area','water']
print("The predicted class is " , predict_image_class(model, img_path, classes))
