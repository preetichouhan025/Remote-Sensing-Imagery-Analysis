# %% [markdown]
# <font color = 'Orange' size = 6> EuroSAT Datatset trained with ENET_b0 Architecture</font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
helper_methods_folder = '/content/drive/MyDrive/AI Project/Model Training/helper_methods'

sys.path.append(os.path.abspath(helper_methods_folder))

# %% [markdown]
# **Importing helper methods for preprocessing, training and plotting**

# %%
from preprocessing import load_data
from plots import plot_data_loader, show_examples
from plots import plot_accuracy, plot_loss,plot_training_batch_loss, plot_confusion_matrix
from training import train_model, compute_accuracy_and_loss
from early_stopping import EarlyStopping
from metrics import compute_classification_report, compute_confusion_matrix
from unnormalize_images import UnNormalize
from predictions import predict_image_class

# %% [markdown]
# **Importing Libraries**

# %%
from torchvision import models
import torch.nn as nn
import torch
import matplotlib.pyplot as plt

# %%
root_dir = r'/content/drive/MyDrive/AI Project/Datasets/EuroSAT'
path_to_save_model=r"/content/drive/MyDrive/AI Project/Model Training/EuroSAT_dataset_weights"
file_name = "EuroSAT_dataset_ENET"

# %% [markdown]
# **Load the datasets into train_loader, validation loader and test loader**

# %%
train_loader, test_loader, valid_loader, data = load_data(root_dir, test_split=0.2, val_split=0.1, batch_size=32, input_size=[64,64])

# %%
# checking the train loader dataset information
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Image batch dimensions: torch.Size([32, 3, 64, 64])
# Image label dimensions: torch.Size([32])
# Class labels of 10 examples: tensor([4, 8, 6, 4, 9, 6, 1, 7, 1, 1])

# %% [markdown]
# **Encodings for the classes**

# %%
label_encoding = data.class_to_idx  
print("label mapping is ", label_encoding)   # save these mapping for predicition
# Out:
# label mapping is  {'AnnualCrop': 0, 'Forest': 1, 'HerbaceousVegetation': 2, 'Highway': 3, 'Industrial': 4, 'Pasture': 5, 'PermanentCrop': 6, 'Residential': 7, 'River': 8, 'SeaLake': 9}

# %% [markdown]
# **Plot the data loader**

# %%
plot_data_loader(train_loader, (4,4))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Load Enet_b0 Model**

# %%
model = models.efficientnet_b0(pretrained=False)  # By default, no pre-trained weights are used.
print(model)
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %% [markdown]
# **Change the number of outputs classes in the last layer of the model**

# %%
num_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_features, 10) #num_classes = 10
print(model)
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# **Set the hyperparameters**

# %%
# define the loss function for multi-class classifictaion
criterion = nn.CrossEntropyLoss()


#Adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0001)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 3, verbose=False)

# create and early stopping object which will be used during the training
early_stopping = EarlyStopping(tolerance=3, min_delta=0.001)

num_epochs = 40

# %% [markdown]
# **Train the Model with train_loader and perform validation with valid_loader**

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(42)
print("Device: {}".format(device))

model.to(device)

minibatch_loss_list, train_acc_list, valid_acc_list, train_loss_list, valid_loss_list = train_model(
    model=model,
    num_epochs=num_epochs,
    train_loader=train_loader,
    valid_loader=valid_loader,
    criterion = criterion,
    optimizer=optimizer,
    device=device,
    early_stopping=early_stopping,
    file_name = file_name,
    path_to_save_model=path_to_save_model,
    scheduler=scheduler)
# Out:
# Device: cuda:0
# Epoch: 001/040 | Batch 0000/0591 | Loss: 2.3244
# Epoch: 001/040 | Batch 0100/0591 | Loss: 2.1921
# Epoch: 001/040 | Batch 0200/0591 | Loss: 2.0951
# Epoch: 001/040 | Batch 0300/0591 | Loss: 1.8807
# Epoch: 001/040 | Batch 0400/0591 | Loss: 1.8144
# Epoch: 001/040 | Batch 0500/0591 | Loss: 1.5640
# Epoch: 001/040 | Train ACC: 23.44% | Validation ACC: 39.44%| Train LOSS: 2.0212| Validation LOSS: 1.7338
# Time elapsed: 261.29 min
# Epoch: 002/040 | Batch 0000/0591 | Loss: 1.8397
# Epoch: 002/040 | Batch 0100/0591 | Loss: 1.7929
# Epoch: 002/040 | Batch 0200/0591 | Loss: 1.7568
# Epoch: 002/040 | Batch 0300/0591 | Loss: 1.7491
# Epoch: 002/040 | Batch 0400/0591 | Loss: 1.6370
# Epoch: 002/040 | Batch 0500/0591 | Loss: 1.4450
# Epoch: 002/040 | Train ACC: 42.71% | Validation ACC: 51.30%| Train LOSS: 1.6528| Validation LOSS: 1.4090
# Time elapsed: 262.54 min
# Epoch: 003/040 | Batch 0000/0591 | Loss: 1.4812
# Epoch: 003/040 | Batch 0100/0591 | Loss: 1.6683
# Epoch: 003/040 | Batch 0200/0591 | Loss: 1.3347
# Epoch: 003/040 | Batch 0300/0591 | Loss: 1.5472
# Epoch: 003/040 | Batch 0400/0591 | Loss: 1.1536
# Epoch: 003/040 | Batch 0500/0591 | Loss: 1.3970
# Epoch: 003/040 | Train ACC: 51.56% | Validation ACC: 58.44%| Train LOSS: 1.4478| Validation LOSS: 1.2123
# Time elapsed: 263.75 min
# Epoch: 004/040 | Batch 0000/0591 | Loss: 1.0905
# Epoch: 004/040 | Batch 0100/0591 | Loss: 1.4772
# Epoch: 004/040 | Batch 0200/0591 | Loss: 1.3032
# Epoch: 004/040 | Batch 0300/0591 | Loss: 1.3937
# Epoch: 004/040 | Batch 0400/0591 | Loss: 1.3532
# Epoch: 004/040 | Batch 0500/0591 | Loss: 1.3540
# Epoch: 004/040 | Train ACC: 56.77% | Validation ACC: 55.07%| Train LOSS: 1.3929| Validation LOSS: 1.2778
# Time elapsed: 264.96 min
# Epoch: 005/040 | Batch 0000/0591 | Loss: 1.2321
# Epoch: 005/040 | Batch 0100/0591 | Loss: 1.5159
# Epoch: 005/040 | Batch 0200/0591 | Loss: 1.6918
# Epoch: 005/040 | Batch 0300/0591 | Loss: 1.6303
# Epoch: 005/040 | Batch 0400/0591 | Loss: 0.9084
# Epoch: 005/040 | Batch 0500/0591 | Loss: 1.4262
# Epoch: 005/040 | Train ACC: 50.52% | Validation ACC: 59.11%| Train LOSS: 1.3704| Validation LOSS: 1.1789
# Time elapsed: 266.20 min
# Epoch: 006/040 | Batch 0000/0591 | Loss: 1.5438
# Epoch: 006/040 | Batch 0100/0591 | Loss: 1.5528
# Epoch: 006/040 | Batch 0200/0591 | Loss: 1.0800
# Epoch: 006/040 | Batch 0300/0591 | Loss: 1.4280
# Epoch: 006/040 | Batch 0400/0591 | Loss: 1.3371
# Epoch: 006/040 | Batch 0500/0591 | Loss: 1.1050
# Epoch: 006/040 | Train ACC: 51.56% | Validation ACC: 61.04%| Train LOSS: 1.2866| Validation LOSS: 1.0972
# Time elapsed: 267.45 min
# Epoch: 007/040 | Batch 0000/0591 | Loss: 0.9573
# Epoch: 007/040 | Batch 0100/0591 | Loss: 0.9072
# Epoch: 007/040 | Batch 0200/0591 | Loss: 1.1212
# Epoch: 007/040 | Batch 0300/0591 | Loss: 1.3146
# Epoch: 007/040 | Batch 0400/0591 | Loss: 1.1405
# Epoch: 007/040 | Batch 0500/0591 | Loss: 1.1805
# Epoch: 007/040 | Train ACC: 59.38% | Validation ACC: 65.41%| Train LOSS: 1.2006| Validation LOSS: 0.9863
# Time elapsed: 268.67 min
# Epoch: 008/040 | Batch 0000/0591 | Loss: 1.5094
# Epoch: 008/040 | Batch 0100/0591 | Loss: 1.3328
# Epoch: 008/040 | Batch 0200/0591 | Loss: 1.0841
# Epoch: 008/040 | Batch 0300/0591 | Loss: 0.8976
# Epoch: 008/040 | Batch 0400/0591 | Loss: 0.8719
# Epoch: 008/040 | Batch 0500/0591 | Loss: 1.1971
# Epoch: 008/040 | Train ACC: 56.77% | Validation ACC: 67.26%| Train LOSS: 1.1021| Validation LOSS: 0.9050
# Time elapsed: 269.89 min
# Saving intermediate model weights
# Epoch: 009/040 | Batch 0000/0591 | Loss: 1.5757
# Epoch: 009/040 | Batch 0100/0591 | Loss: 1.0353
# Epoch: 009/040 | Batch 0200/0591 | Loss: 1.2006
# Epoch: 009/040 | Batch 0300/0591 | Loss: 0.9427
# Epoch: 009/040 | Batch 0400/0591 | Loss: 0.9620
# Epoch: 009/040 | Batch 0500/0591 | Loss: 0.9821
# Epoch: 009/040 | Train ACC: 57.29% | Validation ACC: 69.96%| Train LOSS: 1.0257| Validation LOSS: 0.8512
# Time elapsed: 271.10 min
# Epoch: 010/040 | Batch 0000/0591 | Loss: 1.2484
# Epoch: 010/040 | Batch 0100/0591 | Loss: 0.8629
# Epoch: 010/040 | Batch 0200/0591 | Loss: 1.1076
# Epoch: 010/040 | Batch 0300/0591 | Loss: 1.1300
# Epoch: 010/040 | Batch 0400/0591 | Loss: 0.9475
# Epoch: 010/040 | Batch 0500/0591 | Loss: 1.1485
# Epoch: 010/040 | Train ACC: 57.29% | Validation ACC: 68.52%| Train LOSS: 1.0127| Validation LOSS: 0.8466
# Time elapsed: 272.33 min
# Epoch: 011/040 | Batch 0000/0591 | Loss: 0.9786
# Epoch: 011/040 | Batch 0100/0591 | Loss: 0.9146
# Epoch: 011/040 | Batch 0200/0591 | Loss: 0.9865
# Epoch: 011/040 | Batch 0300/0591 | Loss: 1.0571
# Epoch: 011/040 | Batch 0400/0591 | Loss: 0.8708
# Epoch: 011/040 | Batch 0500/0591 | Loss: 1.1480
# Epoch: 011/040 | Train ACC: 64.58% | Validation ACC: 70.44%| Train LOSS: 1.0027| Validation LOSS: 0.8293
# Time elapsed: 273.57 min
# Epoch: 012/040 | Batch 0000/0591 | Loss: 0.9799
# Epoch: 012/040 | Batch 0100/0591 | Loss: 0.9379
# Epoch: 012/040 | Batch 0200/0591 | Loss: 0.9612
# Epoch: 012/040 | Batch 0300/0591 | Loss: 1.2436
# Epoch: 012/040 | Batch 0400/0591 | Loss: 1.1662
# Epoch: 012/040 | Batch 0500/0591 | Loss: 0.7405
# Epoch: 012/040 | Train ACC: 65.10% | Validation ACC: 70.30%| Train LOSS: 0.9913| Validation LOSS: 0.8328
# Time elapsed: 274.78 min
# Epoch: 013/040 | Batch 0000/0591 | Loss: 1.0306
# Epoch: 013/040 | Batch 0100/0591 | Loss: 0.8261
# Epoch: 013/040 | Batch 0200/0591 | Loss: 0.8082
# Epoch: 013/040 | Batch 0300/0591 | Loss: 0.9952
# Epoch: 013/040 | Batch 0400/0591 | Loss: 0.9152
# Epoch: 013/040 | Batch 0500/0591 | Loss: 0.8560
# Epoch: 013/040 | Train ACC: 68.75% | Validation ACC: 70.26%| Train LOSS: 0.9873| Validation LOSS: 0.8455
# Time elapsed: 276.00 min
# Epoch: 014/040 | Batch 0000/0591 | Loss: 1.0572
# Epoch: 014/040 | Batch 0100/0591 | Loss: 1.1051
# Epoch: 014/040 | Batch 0200/0591 | Loss: 0.8645
# Epoch: 014/040 | Batch 0300/0591 | Loss: 0.6721
# Epoch: 014/040 | Batch 0400/0591 | Loss: 1.1165
# Epoch: 014/040 | Batch 0500/0591 | Loss: 1.2564
# Epoch: 014/040 | Train ACC: 65.10% | Validation ACC: 73.33%| Train LOSS: 0.9246| Validation LOSS: 0.7642
# Time elapsed: 277.22 min
# Epoch: 015/040 | Batch 0000/0591 | Loss: 0.7791
# Epoch: 015/040 | Batch 0100/0591 | Loss: 1.0068
# Epoch: 015/040 | Batch 0200/0591 | Loss: 0.7526
# Epoch: 015/040 | Batch 0300/0591 | Loss: 0.7933
# Epoch: 015/040 | Batch 0400/0591 | Loss: 0.8789
# Epoch: 015/040 | Batch 0500/0591 | Loss: 0.7320
# Epoch: 015/040 | Train ACC: 70.31% | Validation ACC: 73.96%| Train LOSS: 0.8546| Validation LOSS: 0.7601
# Time elapsed: 278.47 min
# Epoch: 016/040 | Batch 0000/0591 | Loss: 1.1415
# Epoch: 016/040 | Batch 0100/0591 | Loss: 0.6213
# Epoch: 016/040 | Batch 0200/0591 | Loss: 0.6298
# Epoch: 016/040 | Batch 0300/0591 | Loss: 0.6527
# Epoch: 016/040 | Batch 0400/0591 | Loss: 0.7443
# Epoch: 016/040 | Batch 0500/0591 | Loss: 0.9686
# Epoch: 016/040 | Train ACC: 69.79% | Validation ACC: 73.33%| Train LOSS: 0.8247| Validation LOSS: 0.7560
# Time elapsed: 279.68 min
# Saving intermediate model weights
# Epoch: 017/040 | Batch 0000/0591 | Loss: 0.8420
# Epoch: 017/040 | Batch 0100/0591 | Loss: 0.8365
# Epoch: 017/040 | Batch 0200/0591 | Loss: 0.8875
# Epoch: 017/040 | Batch 0300/0591 | Loss: 1.1909
# Epoch: 017/040 | Batch 0400/0591 | Loss: 0.6443
# Epoch: 017/040 | Batch 0500/0591 | Loss: 0.5701
# Epoch: 017/040 | Train ACC: 70.83% | Validation ACC: 75.33%| Train LOSS: 0.8261| Validation LOSS: 0.6851
# Time elapsed: 280.91 min
# Epoch: 018/040 | Batch 0000/0591 | Loss: 1.0252
# Epoch: 018/040 | Batch 0100/0591 | Loss: 0.6653
# Epoch: 018/040 | Batch 0200/0591 | Loss: 0.9572
# Epoch: 018/040 | Batch 0300/0591 | Loss: 1.1131
# Epoch: 018/040 | Batch 0400/0591 | Loss: 0.9454
# Epoch: 018/040 | Batch 0500/0591 | Loss: 0.8543
# Epoch: 018/040 | Train ACC: 63.54% | Validation ACC: 74.04%| Train LOSS: 0.8463| Validation LOSS: 0.7252
# Time elapsed: 282.12 min
# Epoch: 019/040 | Batch 0000/0591 | Loss: 1.1761
# Epoch: 019/040 | Batch 0100/0591 | Loss: 1.1478
# Epoch: 019/040 | Batch 0200/0591 | Loss: 0.7728
# Epoch: 019/040 | Batch 0300/0591 | Loss: 0.4730
# Epoch: 019/040 | Batch 0400/0591 | Loss: 0.8656
# Epoch: 019/040 | Batch 0500/0591 | Loss: 0.8053
# Epoch: 019/040 | Train ACC: 67.19% | Validation ACC: 75.07%| Train LOSS: 0.8418| Validation LOSS: 0.7140
# Time elapsed: 283.37 min
# Epoch: 020/040 | Batch 0000/0591 | Loss: 0.5729
# Epoch: 020/040 | Batch 0100/0591 | Loss: 0.6620
# Epoch: 020/040 | Batch 0200/0591 | Loss: 0.9406
# Epoch: 020/040 | Batch 0300/0591 | Loss: 1.2061
# Epoch: 020/040 | Batch 0400/0591 | Loss: 0.5862
# Epoch: 020/040 | Batch 0500/0591 | Loss: 0.7726
# Epoch: 020/040 | Train ACC: 73.44% | Validation ACC: 75.78%| Train LOSS: 0.7960| Validation LOSS: 0.7240
# Time elapsed: 284.59 min
# Epoch: 021/040 | Batch 0000/0591 | Loss: 0.7865
# Epoch: 021/040 | Batch 0100/0591 | Loss: 0.6164
# Epoch: 021/040 | Batch 0200/0591 | Loss: 0.4702
# Epoch: 021/040 | Batch 0300/0591 | Loss: 0.5138
# Epoch: 021/040 | Batch 0400/0591 | Loss: 1.0118
# Epoch: 021/040 | Batch 0500/0591 | Loss: 0.4453
# Epoch: 021/040 | Train ACC: 79.17% | Validation ACC: 77.15%| Train LOSS: 0.7363| Validation LOSS: 0.6607
# Time elapsed: 285.79 min
# Epoch: 022/040 | Batch 0000/0591 | Loss: 0.7047
# Epoch: 022/040 | Batch 0100/0591 | Loss: 1.0999
# Epoch: 022/040 | Batch 0200/0591 | Loss: 0.4858
# Epoch: 022/040 | Batch 0300/0591 | Loss: 1.1114
# Epoch: 022/040 | Batch 0400/0591 | Loss: 1.0021
# Epoch: 022/040 | Batch 0500/0591 | Loss: 0.7335
# Epoch: 022/040 | Train ACC: 70.31% | Validation ACC: 77.37%| Train LOSS: 0.7326| Validation LOSS: 0.6408
# Time elapsed: 287.00 min
# Epoch: 023/040 | Batch 0000/0591 | Loss: 0.7390
# Epoch: 023/040 | Batch 0100/0591 | Loss: 0.9898
# Epoch: 023/040 | Batch 0200/0591 | Loss: 0.4395
# Epoch: 023/040 | Batch 0300/0591 | Loss: 0.8925
# Epoch: 023/040 | Batch 0400/0591 | Loss: 0.8312
# Epoch: 023/040 | Batch 0500/0591 | Loss: 0.4460
# Epoch: 023/040 | Train ACC: 74.48% | Validation ACC: 78.74%| Train LOSS: 0.7170| Validation LOSS: 0.6154
# Time elapsed: 288.20 min
# Epoch: 024/040 | Batch 0000/0591 | Loss: 0.6418
# Epoch: 024/040 | Batch 0100/0591 | Loss: 0.7051
# Epoch: 024/040 | Batch 0200/0591 | Loss: 0.7109
# Epoch: 024/040 | Batch 0300/0591 | Loss: 0.6799
# Epoch: 024/040 | Batch 0400/0591 | Loss: 0.8290
# Epoch: 024/040 | Batch 0500/0591 | Loss: 0.5440
# Epoch: 024/040 | Train ACC: 75.52% | Validation ACC: 77.22%| Train LOSS: 0.7430| Validation LOSS: 0.6873
# Time elapsed: 289.43 min
# Saving intermediate model weights
# Epoch: 025/040 | Batch 0000/0591 | Loss: 0.7553
# Epoch: 025/040 | Batch 0100/0591 | Loss: 0.9739
# Epoch: 025/040 | Batch 0200/0591 | Loss: 0.9443
# Epoch: 025/040 | Batch 0300/0591 | Loss: 0.7394
# Epoch: 025/040 | Batch 0400/0591 | Loss: 0.7700
# Epoch: 025/040 | Batch 0500/0591 | Loss: 0.7362
# Epoch: 025/040 | Train ACC: 68.23% | Validation ACC: 77.67%| Train LOSS: 0.7451| Validation LOSS: 0.6298
# Time elapsed: 290.63 min
# Epoch: 026/040 | Batch 0000/0591 | Loss: 0.7856
# Epoch: 026/040 | Batch 0100/0591 | Loss: 0.6894
# Epoch: 026/040 | Batch 0200/0591 | Loss: 1.0374
# Epoch: 026/040 | Batch 0300/0591 | Loss: 0.8412
# Epoch: 026/040 | Batch 0400/0591 | Loss: 0.9084
# Epoch: 026/040 | Batch 0500/0591 | Loss: 0.6533
# Epoch: 026/040 | Train ACC: 70.83% | Validation ACC: 79.93%| Train LOSS: 0.7028| Validation LOSS: 0.5920
# Time elapsed: 291.83 min
# Epoch: 027/040 | Batch 0000/0591 | Loss: 0.6581
# Epoch: 027/040 | Batch 0100/0591 | Loss: 1.0940
# Epoch: 027/040 | Batch 0200/0591 | Loss: 0.5859
# Epoch: 027/040 | Batch 0300/0591 | Loss: 0.8779
# Epoch: 027/040 | Batch 0400/0591 | Loss: 0.5993
# Epoch: 027/040 | Batch 0500/0591 | Loss: 0.8927
# Epoch: 027/040 | Train ACC: 68.23% | Validation ACC: 79.74%| Train LOSS: 0.6397| Validation LOSS: 0.5771
# Time elapsed: 293.03 min
# Epoch: 028/040 | Batch 0000/0591 | Loss: 0.4121
# Epoch: 028/040 | Batch 0100/0591 | Loss: 0.7080
# Epoch: 028/040 | Batch 0200/0591 | Loss: 0.4170
# Epoch: 028/040 | Batch 0300/0591 | Loss: 0.9512
# Epoch: 028/040 | Batch 0400/0591 | Loss: 0.5820
# Epoch: 028/040 | Batch 0500/0591 | Loss: 0.8533
# Epoch: 028/040 | Train ACC: 73.44% | Validation ACC: 79.70%| Train LOSS: 0.6319| Validation LOSS: 0.6047
# Time elapsed: 294.24 min
# Epoch: 029/040 | Batch 0000/0591 | Loss: 0.5066
# Epoch: 029/040 | Batch 0100/0591 | Loss: 0.6492
# Epoch: 029/040 | Batch 0200/0591 | Loss: 0.7344
# Epoch: 029/040 | Batch 0300/0591 | Loss: 0.5979
# Epoch: 029/040 | Batch 0400/0591 | Loss: 0.4272
# Epoch: 029/040 | Batch 0500/0591 | Loss: 0.7270
# Epoch: 029/040 | Train ACC: 76.56% | Validation ACC: 79.70%| Train LOSS: 0.6285| Validation LOSS: 0.5969
# Time elapsed: 295.48 min
# Epoch: 030/040 | Batch 0000/0591 | Loss: 0.6574
# Epoch: 030/040 | Batch 0100/0591 | Loss: 0.8391
# Epoch: 030/040 | Batch 0200/0591 | Loss: 0.7681
# Epoch: 030/040 | Batch 0300/0591 | Loss: 0.6156
# Epoch: 030/040 | Batch 0400/0591 | Loss: 0.5384
# Epoch: 030/040 | Batch 0500/0591 | Loss: 0.4685
# Epoch: 030/040 | Train ACC: 76.56% | Validation ACC: 79.74%| Train LOSS: 0.6593| Validation LOSS: 0.5698
# Time elapsed: 296.68 min
# Epoch: 031/040 | Batch 0000/0591 | Loss: 0.5885
# Epoch: 031/040 | Batch 0100/0591 | Loss: 0.7202
# Epoch: 031/040 | Batch 0200/0591 | Loss: 0.7968
# Epoch: 031/040 | Batch 0300/0591 | Loss: 0.5803
# Epoch: 031/040 | Batch 0400/0591 | Loss: 0.6381
# Epoch: 031/040 | Batch 0500/0591 | Loss: 0.3997
# Epoch: 031/040 | Train ACC: 77.08% | Validation ACC: 80.07%| Train LOSS: 0.6640| Validation LOSS: 0.5680
# Time elapsed: 297.89 min
# Epoch: 032/040 | Batch 0000/0591 | Loss: 0.6526
# Epoch: 032/040 | Batch 0100/0591 | Loss: 0.5831
# Epoch: 032/040 | Batch 0200/0591 | Loss: 0.6648
# Epoch: 032/040 | Batch 0300/0591 | Loss: 0.5985
# Epoch: 032/040 | Batch 0400/0591 | Loss: 0.6010
# Epoch: 032/040 | Batch 0500/0591 | Loss: 0.5791
# Epoch: 032/040 | Train ACC: 76.56% | Validation ACC: 80.59%| Train LOSS: 0.6184| Validation LOSS: 0.5568
# Time elapsed: 299.08 min
# Saving intermediate model weights
# Epoch: 033/040 | Batch 0000/0591 | Loss: 0.8394
# Epoch: 033/040 | Batch 0100/0591 | Loss: 0.5516
# Epoch: 033/040 | Batch 0200/0591 | Loss: 0.5848
# Epoch: 033/040 | Batch 0300/0591 | Loss: 0.3283
# Epoch: 033/040 | Batch 0400/0591 | Loss: 0.5614
# Epoch: 033/040 | Batch 0500/0591 | Loss: 0.9339
# Epoch: 033/040 | Train ACC: 79.69% | Validation ACC: 81.67%| Train LOSS: 0.5735| Validation LOSS: 0.5212
# Time elapsed: 300.30 min
# Epoch: 034/040 | Batch 0000/0591 | Loss: 0.7707
# Epoch: 034/040 | Batch 0100/0591 | Loss: 0.5126
# Epoch: 034/040 | Batch 0200/0591 | Loss: 0.6570
# Epoch: 034/040 | Batch 0300/0591 | Loss: 0.8132
# Epoch: 034/040 | Batch 0400/0591 | Loss: 0.5832
# Epoch: 034/040 | Batch 0500/0591 | Loss: 0.5293
# Epoch: 034/040 | Train ACC: 78.12% | Validation ACC: 80.41%| Train LOSS: 0.5623| Validation LOSS: 0.5689
# Time elapsed: 301.50 min
# Epoch: 035/040 | Batch 0000/0591 | Loss: 0.3260
# Epoch: 035/040 | Batch 0100/0591 | Loss: 0.7435
# Epoch: 035/040 | Batch 0200/0591 | Loss: 0.6060
# Epoch: 035/040 | Batch 0300/0591 | Loss: 0.9222
# Epoch: 035/040 | Batch 0400/0591 | Loss: 0.4126
# Epoch: 035/040 | Batch 0500/0591 | Loss: 0.4828
# Epoch: 035/040 | Train ACC: 78.65% | Validation ACC: 82.85%| Train LOSS: 0.5642| Validation LOSS: 0.4975
# Time elapsed: 302.70 min
# Epoch: 036/040 | Batch 0000/0591 | Loss: 0.5946
# Epoch: 036/040 | Batch 0100/0591 | Loss: 0.8842
# Epoch: 036/040 | Batch 0200/0591 | Loss: 0.6670
# Epoch: 036/040 | Batch 0300/0591 | Loss: 0.3216
# Epoch: 036/040 | Batch 0400/0591 | Loss: 0.5363
# Epoch: 036/040 | Batch 0500/0591 | Loss: 0.3921
# Epoch: 036/040 | Train ACC: 81.25% | Validation ACC: 81.67%| Train LOSS: 0.5898| Validation LOSS: 0.5222
# Time elapsed: 303.89 min
# Epoch: 037/040 | Batch 0000/0591 | Loss: 0.4050
# Epoch: 037/040 | Batch 0100/0591 | Loss: 0.7584
# Epoch: 037/040 | Batch 0200/0591 | Loss: 0.4237
# Epoch: 037/040 | Batch 0300/0591 | Loss: 0.4173
# Epoch: 037/040 | Batch 0400/0591 | Loss: 0.6470
# Epoch: 037/040 | Batch 0500/0591 | Loss: 0.6570
# Epoch: 037/040 | Train ACC: 83.33% | Validation ACC: 82.41%| Train LOSS: 0.5937| Validation LOSS: 0.5144
# Time elapsed: 305.08 min
# Epoch: 038/040 | Batch 0000/0591 | Loss: 0.6032
# Epoch: 038/040 | Batch 0100/0591 | Loss: 0.7742
# Epoch: 038/040 | Batch 0200/0591 | Loss: 0.3672
# Epoch: 038/040 | Batch 0300/0591 | Loss: 0.5052
# Epoch: 038/040 | Batch 0400/0591 | Loss: 0.4347
# Epoch: 038/040 | Batch 0500/0591 | Loss: 0.5142
# Epoch: 038/040 | Train ACC: 81.25% | Validation ACC: 82.59%| Train LOSS: 0.5633| Validation LOSS: 0.4987
# Time elapsed: 306.30 min
# Epoch: 039/040 | Batch 0000/0591 | Loss: 0.3796
# Epoch: 039/040 | Batch 0100/0591 | Loss: 0.3662
# Epoch: 039/040 | Batch 0200/0591 | Loss: 0.6741
# Epoch: 039/040 | Batch 0300/0591 | Loss: 0.3132
# Epoch: 039/040 | Batch 0400/0591 | Loss: 0.3425
# Epoch: 039/040 | Batch 0500/0591 | Loss: 0.6777
# Epoch: 039/040 | Train ACC: 84.90% | Validation ACC: 83.04%| Train LOSS: 0.5089| Validation LOSS: 0.4898
# Time elapsed: 307.50 min
# Epoch: 040/040 | Batch 0000/0591 | Loss: 0.3847
# Epoch: 040/040 | Batch 0100/0591 | Loss: 0.7953
# Epoch: 040/040 | Batch 0200/0591 | Loss: 0.2724
# Epoch: 040/040 | Batch 0300/0591 | Loss: 0.7145
# Epoch: 040/040 | Batch 0400/0591 | Loss: 0.5173
# Epoch: 040/040 | Batch 0500/0591 | Loss: 0.4734
# Epoch: 040/040 | Train ACC: 79.69% | Validation ACC: 83.96%| Train LOSS: 0.4919| Validation LOSS: 0.4577
# Time elapsed: 308.70 min
# Saving intermediate model weights
# Total Training Time: 308.70 min
# Saving FINAL model weights

# %% [markdown]
# **Test Accuracy and test loss**

# %%
test_acc, test_loss= compute_accuracy_and_loss(model, test_loader,criterion, device=torch.device('cpu'))
print(f'Test Accuracy {test_acc :.2f}%')
print(f'Test Loss {test_loss :.4f}')
# Out:
# Test Accuracy 86.07%
# Test Loss 0.4029

# %% [markdown]
# **Plot the Training Mini_Batch_loss**

# %%
plot_training_batch_loss(minibatch_loss_list, num_epochs, len(train_loader))
plt.show()

# %% [markdown]
# **Plot train vs Validation Accuracy**

# %%
plot_accuracy(train_acc_list, valid_acc_list)
plt.show()

# %% [markdown]
# **Plot train vs Validation Loss**

# %%
plot_loss(train_loss_list, valid_loss_list)
plt.show()

# %% [markdown]
# **Saving the loss and accuracy into file for later model comparison**

# %%
eurosat_dataset_output_dict = {"train_acc_list":train_acc_list,"valid_acc_list":valid_acc_list, "train_loss_list":train_loss_list, "valid_loss_list": valid_loss_list}

import json 

#writing this dict to a file for later use
with open('/content/drive/MyDrive/AI Project/Model Training/EuroSAT_dataset_results_enet.txt', 'w') as f:
    f.write(json.dumps(eurosat_dataset_output_dict))

# %% [markdown]
# **Confusion Matrix**

# %%
label_encoding = data.class_to_idx

class_dict = {v: k for k, v in label_encoding.items()} #reverse the mapping

print(label_encoding)
# Out:
# {'AnnualCrop': 0, 'Forest': 1, 'HerbaceousVegetation': 2, 'Highway': 3, 'Industrial': 4, 'Pasture': 5, 'PermanentCrop': 6, 'Residential': 7, 'River': 8, 'SeaLake': 9}

# %%
# label_encoding ={'AnnualCrop': 0, 'Forest': 1, 'HerbaceousVegetation': 2, 'Highway': 3, 'Industrial': 4, 'Pasture': 5, 'PermanentCrop': 6, 'Residential': 7, 'River': 8, 'SeaLake': 9}  # assign to a variable as it will be needed while prediciting

# %%
confusion_matrix = compute_confusion_matrix(model = model, data_loader = test_loader, device=device)
plot_confusion_matrix(confusion_matrix, class_names = class_dict.values())
plt.show()

# %% [markdown]
# **F1 Score, Precision and Recall**

# %%
print(compute_classification_report(test_loader, model, device=device ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86       587
#            1       0.94      0.93      0.94       621
#            2       0.82      0.73      0.77       673
#            3       0.69      0.80      0.74       420
#            4       0.92      0.90      0.91       480
#            5       0.84      0.85      0.84       386
#            6       0.70      0.77      0.73       487
#            7       0.96      0.91      0.94       650
#            8       0.81      0.81      0.81       505
#            9       0.96      0.94      0.95       591
#
#     accuracy                           0.85      5400
#    macro avg       0.85      0.85      0.85      5400
# weighted avg       0.86      0.85      0.85      5400

# %% [markdown]
# **Predicted labels Visualization**

# %%
# model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

# label_encoding = {'AnnualCrop': 0, 'Forest': 1, 'HerbaceousVegetation': 2, 'Highway': 3, 'Industrial': 4, 'Pasture': 5, 'PermanentCrop': 6, 'Residential': 7, 'River': 8, 'SeaLake': 9}
# class_dict = {v: k for k, v in label_encoding.items()} #reverse the mapping

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %% [markdown]
# **Load the saved model to make predictions**

# %%
model  = torch.load(path_to_save_model + file_name+'_FINAL_MODEL_WEIGHTS.pth', map_location=torch.device('cpu'))

# %%
# test image path 
img_path = '/content/drive/MyDrive/AI Project/Model Training/test_images/water_body_103.jpg'

# %%
classes = ['AnnualCrop','Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']
print("The predicted class is " , predict_image_class(model, img_path, classes))
# Out:
# The predicted class is  SeaLake
